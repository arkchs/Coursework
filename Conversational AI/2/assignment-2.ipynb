# %% [markdown]
# # __Akshat Sharma 102217107__

# %%
import requests
import pandas as pd

# %%
company_names=['apple inc','videocon','intel']
for company in company_names:
    base_url = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords='+company+'&apikey='+API_KEY
    res = requests.get(base_url)
    data = res.json()   
    print(data.get('bestMatches')[0]['1. symbol']+':'+data.get('bestMatches')[0]['2. name'])
# Out:
# AAPL:Apple Inc
# 511389.BSE:Videocon Industries Limited
# INTC:Intel Corp

# %%
base_url1 = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=15min&outputsize=full&apikey='+API_KEY
res1 = requests.get(base_url1)
data1 = res1.json()   

print(data1)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (15min) open, high, low, close prices and volume', '2. Symbol': 'AAPL', '3. Last Refreshed': '2024-09-05 19:45:00', '4. Interval': '15min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}, 'Time Series (15min)': {'2024-09-05 19:45:00': {'1. open': '222.3300', '2. high': '222.4000', '3. low': '222.1500', '4. close': '222.2100', '5. volume': '10657'}, '2024-09-05 19:30:00': {'1. open': '222.3250', '2. high': '222.3900', '3. low': '222.1600', '4. close': '222.3300', '5. volume': '13802'}, '2024-09-05 19:15:00': {'1. open': '222.3000', '2. high': '222.4000', '3. low': '222.0500', '4. close': '222.2900', '5. volume': '4658'}, '2024-09-05 19:00:00': {'1. open': '222.4100', '2. high': '222.4900', '3. low': '222.1500', '4. close': '222.2900', '5. volume': '4938'}, '2024-09-05 18:45:00': {'1. open': '222.1000', '2. high': '222.5800', '3. low': '222.0900', '4. close': '222.4450', '5. volume': '9725'}, '2024-09-05 18:30:00': {'1. open': '222.2300', '2. high': '222.3800', '3. low': '222.0300', '4. close': '222.1000', '5. volume': '10009'}, '2024-09-05 18:15:00': {'1. open': '222.2500', '2. high': '222.4500', '3. low': '222.1500', '4. close': '222.1800', '5. volume': '3643'}, '2024-09-05 18:00:00': {'1. open': '222.3500', '2. high': '222.4900', '3. low': '222.2400', '4. close': '222.4000', '5. volume': '7817'}, '2024-09-05 17:45:00': {'1. open': '222.2500', '2. high': '222.3500', '3. low': '222.1500', '4. close': '222.3500', '5. volume': '3627'}, '2024-09-05 17:30:00': {'1. open': '222.3500', '2. high': '222.4400', '3. low': '222.1500', '4. close': '222.3000', '5. volume': '4700'}, '2024-09-05 17:15:00': {'1. open': '222.3000', '2. high': '222.4900', '3. low': '222.2510', '4. close': '222.4000', '5. volume': '23783'}, '2024-09-05 17:00:00': {'1. open': '222.3450', '2. high': '222.5000', '3. low': '212.8457', '4. close': '222.3200', '5. volume': '8165'}, '2024-09-05 16:45:00': {'1. open': '222.4500', '2. high': '222.4500', '3. low': '209.4246', '4. close': '222.3300', '5. volume': '35908'}, '2024-09-05 16:30:00': {'1. open': '222.1700', '2. high': '222.6700', '3. low': '222.0300', '4. close': '222.4200', '5. volume': '609023'}, '2024-09-05 16:15:00': {'1. open': '222.3900', '2. high': '222.7900', '3. low': '222.0000', '4. close': '222.2400', '5. volume': '123191'}, '2024-09-05 16:00:00': {'1. open': '222.3800', '2. high': '223.3964', '3. low': '221.5800', '4. close': '222.3300', '5. volume': '9533668'}, '2024-09-05 15:45:00': {'1. open': '222.1850', '2. high': '222.4400', '3. low': '221.8101', '4. close': '222.3800', '5. volume': '2480000'}, '2024-09-05 15:30:00': {'1. open': '222.8200', '2. high': '223.4000', '3. low': '222.0300', '4. close': '222.2099', '5. volume': '946932'}, '2024-09-05 15:15:00': {'1. open': '223.0475', '2. high': '223.0700', '3. low': '222.1100', '4. close': '222.8300', '5. volume': '862019'}, '2024-09-05 15:00:00': {'1. open': '223.3300', '2. high': '223.3932', '3. low': '223.0200', '4. close': '223.0400', '5. volume': '506912'}, '2024-09-05 14:45:00': {'1. open': '223.5300', '2. high': '223.9000', '3. low': '223.2805', '4. close': '223.3200', '5. volume': '623005'}, '2024-09-05 14:30:00': {'1. open': '223.3400', '2. high': '223.8000', '3. low': '223.3300', '4. close': '223.5300', '5. volume': '553249'}, '2024-09-05 14:15:00': {'1. open': '223.3000', '2. high': '223.7100', '3. low': '223.1700', '4. close': '223.3305', '5. volume': '708769'}, '2024-09-05 14:00:00': {'1. open': '223.6300', '2. high': '223.7500', '3. low': '223.3000', '4. close': '223.3200', '5. volume': '645055'}, '2024-09-05 13:45:00': {'1. open': '223.2400', '2. high': '223.7400', '3. low': '223.2300', '4. close': '223.6100', '5. volume': '707815'}, '2024-09-05 13:30:00': {'1. open': '222.3977', '2. high': '223.2700', '3. low': '222.3742', '4. close': '223.2400', '5. volume': '728259'}, '2024-09-05 13:15:00': {'1. open': '222.8550', '2. high': '222.9400', '3. low': '222.3400', '4. close': '222.3 ...

# %%
data1.get('Time Series (15min)')
# Out:
# {'2024-09-05 19:45:00': {'1. open': '222.3300',
#   '2. high': '222.4000',
#   '3. low': '222.1500',
#   '4. close': '222.2100',
#   '5. volume': '10657'},
#  '2024-09-05 19:30:00': {'1. open': '222.3250',
#   '2. high': '222.3900',
#   '3. low': '222.1600',
#   '4. close': '222.3300',
#   '5. volume': '13802'},
#  '2024-09-05 19:15:00': {'1. open': '222.3000',
#   '2. high': '222.4000',
#   '3. low': '222.0500',
#   '4. close': '222.2900',
#   '5. volume': '4658'},
#  '2024-09-05 19:00:00': {'1. open': '222.4100',
#   '2. high': '222.4900',
#   '3. low': '222.1500',
#   '4. close': '222.2900',
#   '5. volume': '4938'},
#  '2024-09-05 18:45:00': {'1. open': '222.1000',
#   '2. high': '222.5800',
#   '3. low': '222.0900',
#   '4. close': '222.4450',
#   '5. volume': '9725'},
#  '2024-09-05 18:30:00': {'1. open': '222.2300',
#   '2. high': '222.3800',
#   '3. low': '222.0300',
#   '4. close': '222.1000',
#   '5. volume': '10009'},
#  '2024-09-05 18:15:00': {'1. open': '222.2500',
#   '2. high': '222.4500',
#   '3. low': '222.1500',
#   '4. close': '222.1800',
#   '5. volume': '3643'},
#  '2024-09-05 18:00:00': {'1. open': '222.3500',
#   '2. high': '222.4900',
#   '3. low': '222.2400',
#   '4. close': '222.4000',
#   '5. volume': '7817'},
#  '2024-09-05 17:45:00': {'1. open': '222.2500',
#   '2. high': '222.3500',
#   '3. low': '222.1500',
#   '4. close': '222.3500',
#   '5. volume': '3627'},
#  '2024-09-05 17:30:00': {'1. open': '222.3500',
#   '2. high': '222.4400',
#   '3. low': '222.1500',
#   '4. close': '222.3000',
#   '5. volume': '4700'},
#  '2024-09-05 17:15:00': {'1. open': '222.3000',
#   '2. high': '222.4900',
#   '3. low': '222.2510',
#   '4. close': '222.4000',
#   '5. volume': '23783'},
#  '2024-09-05 17:00:00': {'1. open': '222.3450',
#   '2. high': '222.5000',
#   '3. low': '212.8457',
#   '4. close': '222.3200',
#   '5. volume': '8165'},
#  '2024-09-05 16:45:00': {'1. open': '222.4500',
#   '2. high': '222.4500',
#   '3. low': '209.4246',
#   '4. close': '222.3300',
#   '5. volume': '35908'},
#  '2024-09-05 16:30:00': {'1. open': '222.1700',
#   '2. high': '222.6700',
#   '3. low': '222.0300',
#   '4. close': '222.4200',
#   '5. volume': '609023'},
#  '2024-09-05 16:15:00': {'1. open': '222.3900',
#   '2. high': '222.7900',
#   '3. low': '222.0000',
#   '4. close': '222.2400',
#   '5. volume': '123191'},
#  '2024-09-05 16:00:00': {'1. open': '222.3800',
#   '2. high': '223.3964',
#   '3. low': '221.5800',
#   '4. close': '222.3300',
#   '5. volume': '9533668'},
#  '2024-09-05 15:45:00': {'1. open': '222.1850',
#   '2. high': '222.4400',
#   '3. low': '221.8101',
#   '4. close': '222.3800',
#   '5. volume': '2480000'},
#  '2024-09-05 15:30:00': {'1. open': '222.8200',
#   '2. high': '223.4000',
#   '3. low': '222.0300',
#   '4. close': '222.2099',
#   '5. volume': '946932'},
#  '2024-09-05 15:15:00': {'1. open': '223.0475',
#   '2. high': '223.0700',
#   '3. low': '222.1100',
#   '4. close': '222.8300',
#   '5. volume': '862019'},
#  '2024-09-05 15:00:00': {'1. open': '223.3300',
#   '2. high': '223.3932',
#   '3. low': '223.0200',
#   '4. close': '223.0400',
#   '5. volume': '506912'},
#  '2024-09-05 14:45:00': {'1. open': '223.5300',
#   '2. high': '223.9000',
#   '3. low': '223.2805',
#   '4. close': '223.3200',
#   '5. volume': '623005'},
#  '2024-09-05 14:30:00': {'1. open': '223.3400',
#   '2. high': '223.8000',
#   '3. low': '223.3300',
#   '4. close': '223.5300',
#   '5. volume': '553249'},
#  '2024-09-05 14:15:00': {'1. open': '223.3000',
#   '2. high': '223.7100',
#   '3. low': '223.1700',
#   '4. close': '223.3305',
#   '5. volume': '708769'},
#  '2024-09-05 14:00:00': {'1. open': '223.6300',
#   '2. high': '223.7500',
#   '3. low': '223.3000',
#   '4. close': '223.3200',
#   '5. volume': '645055'},
#  '2024-09-05 13:45:00': {'1. open': '223.2400',
#   '2. high': '223.7400',
#   '3. low': '223.2300',
#   '4. close': '223.6100',
#   '5. volume': '707815'},
#  '2024-09-05 13:30:00': {'1. open': '222.3977',
#   '2. high': '223.2700',
#   '3. low': '222.3742',
#   '4. close': '223.2400',
#   '5. volume': '728259'},
#  '2024-09-05 13:15:00': {'1. open': '222.8550',
#   '2. high': '222.9400',
#   '3. low': '222.3400',
#   '4. close': '222.3900',
#   '5. volume': '517301'},
#  '2024-09-05 13:00:00': {'1. open': '222.8350',
#   '2. high': '222.9850',
#   '3. low': '222.5000',
#   '4. close': '222.8550',
#   '5. volume': '593342'},
#  '2024-09-05 12:45:00': {'1. open': '223.0900',
#   '2. high': '223.1400',
#   '3. low': '222.7000',
#   '4. close': '222.8250',
#   '5. volume': '727829'},
#  '2024-09-05 12:30:00': {'1. open': '222.7900',
#   '2. high': '223.1500',
#   '3. low': '222.6250',
#   '4. close': '223.0600',
#   '5. volume': '586854'},
#  '2024-09-05 12:15:00': {'1. open': '222.2150',
#   '2. high': '222.8196',
#   '3. low': '221.9800',
#   '4. close': '222.7952',
#   '5. volume': '670320'},
#  '2024-09-05 12:00:00': {'1. open': '221.9800',
#   '2. high': '222.7500',
#   '3. low': '221.9562',
#   '4. close': '222.2150',
#   '5. volume': '647316'},
#  '2024-09-05 11:45:00': {'1. open': '222.3400',
#   '2. high': '222.6300',
#   '3. low': '221.8800',
#   '4. close': '221.9700',
#   '5. volume': '844100'},
#  '2024-09-05 11:30:00': {'1. open': '222.4600',
#   '2. high': '222.6600',
#   '3. low': '222.0000',
#   '4. close': '222.3100',
#   '5. volume': '1010255'},
#  '2024-09-05 11:15:00': {'1. open': '223.6300',
#   '2. high': '223.8700',
#   '3. low': '222.3800',
#   '4. close': '222.4800',
#   '5. volume': '1167492'},
#  '2024-09-05 11:00:00': {'1. open': '223.7000',
#   '2. high': '223.8200',
#   '3. low': '222.9850',
#   '4. close': '223.6200',
#   '5. volume': '1258476'},
#  '2024-09-05 10:45:00': {'1. open': '224.6300',
#   '2. high': '224.7200',
#   '3. low': '223.6300',
#   '4. close': '223.7000',
#   '5. volume': '1082548'},
#  '2024-09-05 10:30:00': {'1. open': '225.0900',
#   '2. high': '225.3900',
#   '3. low': '224.6000',
#   '4. close': '224.6600',
#   '5. volume': '1101915'},
#  '2024-09-05 10:15:00': {'1. open': '224.2350',
#   '2. high': '225.4800',
#   '3. low': '224.0100',
#   '4. close': '225.0800',
#   '5. volume': '1558590'},
#  '2024-09-05 10:00:00': {'1. open': '224.7100',
#   '2. high': '225.2300',
#   '3. low': '223.8800',
#   '4. close': '224.2200',
#   '5. volume': '1990315'},
#  '2024-09-05 09:45:00': {'1. open': '223.1500',
#   '2. high': '224.9200',
#   '3. low': '222.8700',
#   '4. close': '224.7100',
#   '5. volume': '1961896'},
#  '2024-09-05 09:30:00': {'1. open': '221.6250',
#   '2. high': '224.3300',
#   '3. low': '221.5200',
#   '4. close': '223.1350',
#   '5. volume': '4520497'},
#  '2024-09-05 09:15:00': {'1. open': '221.1400',
#   '2. high': '221.7600',
#   '3. low': '221.0300',
#   '4. close': '221.6800',
#   '5. volume': '102747'},
#  '2024-09-05 09:00:00': {'1. open': '220.3100',
#   '2. high': '221.6500',
#   '3. low': '220.1300',
#   '4. close': '221.1800',
#   '5. volume': '200264'},
#  '2024-09-05 08:45:00': {'1. open': '220.3700',
#   '2. high': '221.2900',
#   '3. low': '217.8800',
#   '4. close': '220.3700',
#   '5. volume': '23250'},
#  '2024-09-05 08:30:00': {'1. open': '219.7550',
#   '2. high': '229.0000',
#   '3. low': '219.6144',
#   '4. close': '220.0000',
#   '5. volume': '81741'},
#  '2024-09-05 08:15:00': {'1. open': '220.1500',
#   '2. high': '220.3900',
#   '3. low': '219.1100',
#   '4. close': '219.7800',
#   '5. volume': '47636'},
#  '2024-09-05 08:00:00': {'1. open': '220.4887',
#   '2. high': '221.4000',
#   '3. low': '219.7500',
#   '4. close': '220.2300',
#   '5. volume': '77449'},
#  '2024-09-05 07:45:00': {'1. open': '220.9400',
#   '2. high': '220.9400',
#   '3. low': '220.2000',
#   '4. close': '220.5700',
#   '5. volume': '12881'},
#  '2024-09-05 07:30:00': {'1. open': '220.8000',
#   '2. high': '221.1400',
#   '3. low': '220.7800',
#   '4. close': '220.9400',
#   '5. volume': '6764'},
#  '2024-09-05 07:15:00': {'1. open': '220.7400',
#   '2. high': '220.9800',
#   '3. low': '220.5100',
#   '4. close': '220.8000',
#   '5. volume': '5575'},
#  '2024-09-05 07:00:00': {'1. open': '221.1200',
#   '2. high': '221.3900',
#   '3. low': '220.3500',
#   '4. close': '220.6400',
#   '5. volume': '23736'},
#  '2024-09-05 06:45:00': {'1. open': '220.7700',
#   '2. high': '221.4000',
#   '3. low': '220.7600',
#   '4. close': '221.1200',
#   '5. volume': '9735'},
#  '2024-09-05 06:30:00': {'1. open': '220.0000',
#   '2. high': '220.9800',
#   '3. low': '220.0000',
#   '4. close': '220.7900',
#   '5. volume': '29524'},
#  '2024-09-05 06:15:00': {'1. open': '220.0600',
#   '2. high': '220.1500',
#   '3. low': '219.9500',
#   '4. close': '220.0300',
#   '5. volume': '4036'},
#  '2024-09-05 06:00:00': {'1. open': '220.1600',
#   '2. high': '220.2000',
#   '3. low': '219.9200',
#   '4. close': '220.0500',
#   '5. volume': '4416'},
#  '2024-09-05 05:45:00': {'1. open': '220.0000',
#   '2. high': '220.2200',
#   '3. low': '219.9600',
#   '4. close': '220.0800',
#   '5. volume': '2376'},
#  '2024-09-05 05:30:00': {'1. open': '219.9000',
#   '2. high': '220.0800',
#   '3. low': '219.8200',
#   '4. close': '220.0200',
#   '5. volume': '2543'},
#  '2024-09-05 05:15:00': {'1. open': '220.1300',
#   '2. high': '220.2900',
#   '3. low': '219.8400',
#   '4. close': '219.9100',
#   '5. volume': '6267'},
#  '2024-09-05 05:00:00': {'1. open': '220.4800',
#   '2. high': '220.4800',
#   '3. low': '220.0800',
#   '4. close': '220.0800',
#   '5. volume': '4054'},
#  '2024-09-05 04:45:00': {'1. open': '220.3800',
#   '2. high': '220.5000',
#   '3. low': '220.2800',
#   '4. close': '220.4800',
#   '5. volume': '2730'},
#  '2024-09-05 04:30:00': {'1. open': '220.3200',
#   '2. high': '220.4300',
#   '3. low': '220.0800',
#   '4. close': '220.4000',
#   '5. volume': '3583'},
#  '2024-09-05 04:15:00': {'1. open': '220.2100',
#   '2. high': '220.3700',
#   '3. low': '220.0800',
#   '4. close': '220.3400',
#   '5. volume': '6518'},
#  '2024-09-05 04:00:00': {'1. open': '220.6000',
#   '2. high': '220.6700',
#   '3. low': '220.0000',
#   '4. close': '220.2200',
#   '5. volume': '15380'},
#  '2024-09-04 19:45:00': {'1. open': '219.6000',
#   '2. high': '220.1200',
#   '3. low': '219.5071',
#   '4. close': '220.0600',
#   '5. volume': '18782'},
#  '2024-09-04 19:30:00': {'1. open': '220.2000',
#   '2. high': '220.4500',
#   '3. low': '219.2400',
#   '4. close': '219.4500',
#   '5. volume': '15748'},
#  '2024-09-04 19:15:00': {'1. open': '220.6750',
#   '2. high': '220.7600',
#   '3. low': '220.0100',
#   '4. close': '220.4400',
#   '5. volume': '6712'},
#  '2024-09-04 19:00:00': {'1. open': '220.8100',
#   '2. high': '221.0000',
#   '3. low': '220.3100',
#   '4. close': '220.5000',
#   '5. volume': '4758'},
#  '2024-09-04 18:45:00': {'1. open': '220.7500',
#   '2. high': '221.0000',
#   '3. low': '220.7500',
#   '4. close': '220.9000',
#   '5. volume': '8272'},
#  '2024-09-04 18:30:00': {'1. open': '220.8750',
#   '2. high': '220.9500',
#   '3. low': '220.6700',
#   '4. close': '220.8700',
#   '5. volume': '2592'},
#  '2024-09-04 18:15:00': {'1. open': '220.9500',
#   '2. high': '220.9500',
#   '3. low': '220.6700',
#   '4. close': '220.8800',
#   '5. volume': '2931'},
#  '2024-09-04 18:00:00': {'1. open': '220.8800',
#   '2. high': '220.9500',
#   '3. low': '220.8100',
#   '4. close': '220.8800',
#   '5. volume': '3040'},
#  '2024-09-04 17:45:00': {'1. open': '220.8350',
#   '2. high': '220.9500',
#   '3. low': '220.7400',
#   '4. close': '220.9000',
#   '5. volume': '3590'},
#  '2024-09-04 17:30:00': {'1. open': '220.8200',
#   '2. high': '220.9500',
#   '3. low': '220.6600',
#   '4. close': '220.8500',
#   '5. volume': '7833'},
#  '2024-09-04 17:15:00': {'1. open': '220.7100',
#   '2. high': '220.8400',
#   '3. low': '220.6200',
#   '4. close': '220.8395',
#   '5. volume': '3703'},
#  '2024-09-04 17:00:00': {'1. open': '220.6850',
#   '2. high': '220.8500',
#   '3. low': '211.1001',
#   '4. close': '220.8400',
#   '5. volume': '144773'},
#  '2024-09-04 16:45:00': {'1. open': '220.6700',
#   '2. high': '220.8500',
#   '3. low': '220.5500',
#   '4. close': '220.6700',
#   '5. volume': '309429'},
#  '2024-09-04 16:30:00': {'1. open': '220.8070',
#   '2. high': '220.9000',
#   '3. low': '220.5600',
#   '4. close': '220.6300',
#   '5. volume': '45275'},
#  '2024-09-04 16:15:00': {'1. open': '220.5100',
#   '2. high': '220.9000',
#   '3. low': '220.2400',
#   '4. close': '220.6900',
#   '5. volume': '47567'},
#  '2024-09-04 16:00:00': {'1. open': '220.7700',
#   '2. high': '221.7000',
#   '3. low': '219.9133',
#   '4. close': '220.5100',
#   '5. volume': '10461909'},
#  '2024-09-04 15:45:00': {'1. open': '221.1000',
#   '2. high': '221.4301',
#   '3. low': '220.6300',
#   '4. close': '220.7900',
#   '5. volume': '3333710'},
#  '2024-09-04 15:30:00': {'1. open': '220.5500',
#   '2. high': '221.2750',
#   '3. low': '220.4200',
#   '4. close': '221.1099',
#   '5. volume': '1311557'},
#  '2024-09-04 15:15:00': {'1. open': '220.2900',
#   '2. high': '220.5890',
#   '3. low': '220.2000',
#   '4. close': '220.5500',
#   '5. volume': '877684'},
#  '2024-09-04 15:00:00': {'1. open': '220.5200',
#   '2. high': '220.5900',
#   '3. low': '220.1700',
#   '4. close': '220.2900',
#   '5. volume': '807096'},
#  '2024-09-04 14:45:00': {'1. open': '220.8000',
#   '2. high': '220.9700',
#   '3. low': '220.4600',
#   '4. close': '220.5100',
#   '5. volume': '790083'},
#  '2024-09-04 14:30:00': {'1. open': '220.9000',
#   '2. high': '221.1400',
#   '3. low': '220.5000',
#   '4. close': '220.7900',
#   '5. volume': '760586'},
#  '2024-09-04 14:15:00': {'1. open': '220.8901',
#   '2. high': '221.0900',
#   '3. low': '220.4000',
#   '4. close': '220.9100',
#   '5. volume': '766805'},
#  '2024-09-04 14:00:00': {'1. open': '220.8750',
#   '2. high': '221.1100',
#   '3. low': '220.5200',
#   '4. close': '220.8800',
#   '5. volume': '846844'},
#  '2024-09-04 13:45:00': {'1. open': '220.3500',
#   '2. high': '220.9100',
#   '3. low': '220.3500',
#   '4. close': '220.8750',
#   '5. volume': '769711'},
#  '2024-09-04 13:30:00': {'1. open': '220.1046',
#   '2. high': '220.5900',
#   '3. low': '220.0700',
#   '4. close': '220.3300',
#   '5. volume': '700835'},
#  '2024-09-04 13:15:00': {'1. open': '220.1450',
#   '2. high': '220.7843',
#   '3. low': '219.9900',
#   '4. close': '220.1200',
#   '5. volume': '840902'},
#  '2024-09-04 13:00:00': {'1. open': '220.2100',
#   '2. high': '220.3700',
#   '3. low': '219.7900',
#   '4. close': '220.1400',
#   '5. volume': '704434'},
#  '2024-09-04 12:45:00': {'1. open': '219.7000',
#   '2. high': '220.2182',
#   '3. low': '219.5400',
#   '4. close': '220.2150',
#   '5. volume': '802806'},
#  '2024-09-04 12:30:00': {'1. open': '219.9200',
#   '2. high': '220.2000',
#   '3. low': '219.6100',
#   '4. close': '219.7000',
#   '5. volume': '730949'},
#  '2024-09-04 12:15:00': {'1. open': '219.1800',
#   '2. high': '219.9650',
#   '3. low': '219.1800',
#   '4. close': '219.9300',
#   '5. volume': '734541'},
#  '2024-09-04 12:00:00': {'1. open': '219.3150',
#   '2. high': '219.5700',
#   '3. low': '219.0800',
#   '4. close': '219.1900',
#   '5. volume': '759400'},
#  '2024-09-04 11:45:00': {'1. open': '218.8500',
#   '2. high': '219.4595',
#   '3. low': '218.8207',
#   '4. close': '219.3200',
#   '5. volume': '878530'},
#  '2024-09-04 11:30:00': {'1. open': '218.6950',
#   '2. high': '219.0400',
#   '3. low': '218.0100',
#   '4. close': '218.8400',
#   '5. volume': '1138513'},
#  '2024-09-04 11:15:00': {'1. open': '219.4100',
#   '2. high': '219.7800',
#   '3. low': '218.6800',
#   '4. close': '218.6801',
#   '5. volume': '1105475'},
#  '2024-09-04 11:00:00': {'1. open': '219.4800',
#   '2. high': '220.2500',
#   '3. low': '219.1500',
#   '4. close': '219.4000',
#   '5. volume': '1703087'},
#  '2024-09-04 10:45:00': {'1. open': '219.5500',
#   '2. high': '219.6200',
#   '3. low': '218.6500',
#   '4. close': '219.4500',
#   '5. volume': '1566491'},
#  '2024-09-04 10:30:00': {'1. open': '218.6400',
#   '2. high': '219.5600',
#   '3. low': '218.5400',
#   '4. close': '219.5500',
#   '5. volume': '1790111'},
#  '2024-09-04 10:15:00': {'1. open': '218.6500',
#   '2. high': '218.8700',
#   '3. low': '217.4800',
#   '4. close': '218.6350',
#   '5. volume': '2564135'},
#  '2024-09-04 10:00:00': {'1. open': '219.5600',
#   '2. high': '219.5600',
#   '3. low': '217.8019',
#   '4. close': '218.6500',
#   '5. volume': '3691916'},
#  '2024-09-04 09:45:00': {'1. open': '220.1850',
#   '2. high': '220.6200',
#   '3. low': '219.0400',
#   '4. close': '219.5700',
#   '5. volume': '2394394'},
#  '2024-09-04 09:30:00': {'1. open': '221.6600',
#   '2. high': '221.7800',
#   '3. low': '219.3900',
#   '4. close': '220.1950',
#   '5. volume': '4044134'},
#  '2024-09-04 09:15:00': {'1. open': '221.2198',
#   '2. high': '222.7700',
#   '3. low': '220.7500',
#   '4. close': '221.5400',
#   '5. volume': '383605'},
#  '2024-09-04 09:00:00': {'1. open': '221.4800',
#   '2. high': '221.5900',
#   '3. low': '221.2100',
#   '4. close': '221.2200',
#   '5. volume': '26511'},
#  '2024-09-04 08:45:00': {'1. open': '221.2400',
#   '2. high': '221.6000',
#   '3. low': '221.1112',
#   '4. close': '221.4700',
#   '5. volume': '38032'},
#  '2024-09-04 08:30:00': {'1. open': '221.0500',
#   '2. high': '222.7700',
#   '3. low': '220.6500',
#   '4. close': '221.2482',
#   '5. volume': '26330'},
#  '2024-09-04 08:15:00': {'1. open': '220.7900',
#   '2. high': '228.3550',
#   '3. low': '220.7100',
#   '4. close': '221.1400',
#   '5. volume': '17133'},
#  '2024-09-04 08:00:00': {'1. open': '220.7500',
#   '2. high': '222.7700',
#   '3. low': '219.6700',
#   '4. close': '220.8750',
#   '5. volume': '50486'},
#  '2024-09-04 07:45:00': {'1. open': '220.7000',
#   '2. high': '220.9200',
#   '3. low': '220.6800',
#   '4. close': '220.8000',
#   '5. volume': '9690'},
#  '2024-09-04 07:30:00': {'1. open': '220.8900',
#   '2. high': '221.1600',
#   '3. low': '220.7000',
#   '4. close': '220.7300',
#   '5. volume': '10026'},
#  '2024-09-04 07:15:00': {'1. open': '220.7900',
#   '2. high': '220.9200',
#   '3. low': '220.7000',
#   '4. close': '220.9100',
#   '5. volume': '5479'},
#  '2024-09-04 07:00:00': {'1. open': '220.7500',
#   '2. high': '220.9600',
#   '3. low': '220.5300',
#   '4. close': '220.7900',
#   '5. volume': '17638'},
#  '2024-09-04 06:45:00': {'1. open': '220.8000',
#   '2. high': '220.8700',
#   '3. low': '220.6300',
#   '4. close': '220.7500',
#   '5. volume': '7163'},
#  '2024-09-04 06:30:00': {'1. open': '221.0500',
#   '2. high': '221.1600',
#   '3. low': '220.7700',
#   '4. close': '220.7700',
#   '5. volume': '4100'},
#  '2024-09-04 06:15:00': {'1. open': '221.1000',
#   '2. high': '221.1000',
#   '3. low': '220.9300',
#   '4. close': '221.0400',
#   '5. volume': '5106'},
#  '2024-09-04 06:00:00': {'1. open': '221.1300',
#   '2. high': '221.4800',
#   '3. low': '221.0800',
#   '4. close': '221.1200',
#   '5. volume': '5847'},
#  '2024-09-04 05:45:00': {'1. open': '220.9000',
#   '2. high': '221.1400',
#   '3. low': '220.8800',
#   '4. close': '221.1000',
#   '5. volume': '17592'},
#  '2024-09-04 05:30:00': {'1. open': '220.8500',
#   '2. high': '220.9800',
#   '3. low': '220.8000',
#   '4. close': '220.9700',
#   '5. volume': '12677'},
#  '2024-09-04 05:15:00': {'1. open': '220.5600',
#   '2. high': '220.9200',
#   '3. low': '220.5000',
#   '4. close': '220.8500',
#   '5. volume': '16785'},
#  '2024-09-04 05:00:00': {'1. open': '220.5500',
#   '2. high': '220.6900',
#   '3. low': '220.5000',
#   '4. close': '220.5600',
#   '5. volume': '6778'},
#  '2024-09-04 04:45:00': {'1. open': '220.5100',
#   '2. high': '220.5900',
#   '3. low': '220.2100',
#   '4. close': '220.5200',
#   '5. volume': '7840'},
#  '2024-09-04 04:30:00': {'1. open': '220.6900',
#   '2. high': '220.9500',
#   '3. low': '220.5000',
#   '4. close': '220.5000',
#   '5. volume': '9583'},
#  '2024-09-04 04:15:00': {'1. open': '220.5700',
#   '2. high': '220.8400',
#   '3. low': '220.5000',
#   '4. close': '220.6600',
#   '5. volume': '12558'},
#  '2024-09-04 04:00:00': {'1. open': '220.1000',
#   '2. high': '220.9800',
#   '3. low': '220.1000',
#   '4. close': '220.5200',
#   '5. volume': '33962'},
#  '2024-09-03 19:45:00': {'1. open': '220.5500',
#   '2. high': '220.9900',
#   '3. low': '220.3500',
#   '4. close': '220.8750',
#   '5. volume': '25827'},
#  '2024-09-03 19:30:00': {'1. open': '220.5500',
#   '2. high': '220.8300',
#   '3. low': '220.4400',
#   '4. close': '220.5100',
#   '5. volume': '17243'},
#  '2024-09-03 19:15:00': {'1. open': '220.5500',
#   '2. high': '220.9600',
#   '3. low': '220.5000',
#   '4. close': '220.6000',
#   '5. volume': '9172'},
#  '2024-09-03 19:00:00': {'1. open': '220.8500',
#   '2. high': '221.1500',
#   '3. low': '220.2200',
#   '4. close': '220.6000',
#   '5. volume': '40897'},
#  '2024-09-03 18:45:00': {'1. open': '221.2500',
#   '2. high': '221.4000',
#   '3. low': '220.7500',
#   '4. close': '220.9000',
#   '5. volume': '14092'},
#  '2024-09-03 18:30:00': {'1. open': '221.2300',
#   '2. high': '221.4000',
#   '3. low': '221.1200',
#   '4. close': '221.2500',
#   '5. volume': '13248'},
#  '2024-09-03 18:15:00': {'1. open': '221.1900',
#   '2. high': '221.4000',
#   '3. low': '220.9200',
#   '4. close': '221.2800',
#   '5. volume': '22276'},
#  '2024-09-03 18:00:00': {'1. open': '221.3100',
#   '2. high': '221.5500',
#   '3. low': '220.8600',
#   '4. close': '221.1050',
#   '5. volume': '52315'},
#  '2024-09-03 17:45:00': {'1. open': '221.0900',
#   '2. high': '221.4700',
#   '3. low': '221.0220',
#   '4. close': '221.2400',
#   '5. volume': '20788'},
#  '2024-09-03 17:30:00': {'1. open': '221.1150',
#   '2. high': '221.3400',
#   '3. low': '221.0100',
#   '4. close': '221.0900',
#   '5. volume': '20861'},
#  '2024-09-03 17:15:00': {'1. open': '221.2800',
#   '2. high': '222.7700',
#   '3. low': '221.0900',
#   '4. close': '221.1300',
#   '5. volume': '253854'},
#  '2024-09-03 17:00:00': {'1. open': '222.1000',
#   '2. high': '229.2480',
#   '3. low': '206.7475',
#   '4. close': '221.2650',
#   '5. volume': '51402'},
#  '2024-09-03 16:45:00': {'1. open': '221.8900',
#   '2. high': '229.2480',
#   '3. low': '207.7080',
#   '4. close': '221.9350',
#   '5. volume': '64417'},
#  '2024-09-03 16:30:00': {'1. open': '221.7700',
#   '2. high': '222.7700',
#   '3. low': '221.7350',
#   '4. close': '221.8600',
#   '5. volume': '1399750'},
#  '2024-09-03 16:15:00': {'1. open': '222.3350',
#   '2. high': '222.7700',
#   '3. low': '221.6750',
#   '4. close': '221.7700',
#   '5. volume': '102307'},
#  '2024-09-03 16:00:00': {'1. open': '222.7600',
#   '2. high': '224.0515',
#   '3. low': '222.1500',
#   '4. close': '222.3247',
#   '5. volume': '17070708'},
#  '2024-09-03 15:45:00': {'1. open': '221.8600',
#   '2. high': '222.8000',
#   '3. low': '221.1700',
#   '4. close': '222.7600',
#   '5. volume': '4981677'},
#  '2024-09-03 15:30:00': {'1. open': '222.4400',
#   '2. high': '222.5250',
#   '3. low': '221.5700',
#   '4. close': '221.8450',
#   '5. volume': '1657666'},
#  '2024-09-03 15:15:00': {'1. open': '222.3500',
#   '2. high': '222.7150',
#   '3. low': '222.1600',
#   '4. close': '222.4500',
#   '5. volume': '1514758'},
#  '2024-09-03 15:00:00': {'1. open': '221.9450',
#   '2. high': '222.4200',
#   '3. low': '221.7700',
#   '4. close': '222.3436',
#   '5. volume': '1016682'},
#  '2024-09-03 14:45:00': {'1. open': '222.1400',
#   '2. high': '222.3800',
#   '3. low': '221.8200',
#   '4. close': '221.9350',
#   '5. volume': '849840'},
#  '2024-09-03 14:30:00': {'1. open': '222.1300',
#   '2. high': '222.7300',
#   '3. low': '222.0500',
#   '4. close': '222.1400',
#   '5. volume': '955709'},
#  '2024-09-03 14:15:00': {'1. open': '222.3800',
#   '2. high': '222.4000',
#   '3. low': '221.8400',
#   '4. close': '222.1300',
#   '5. volume': '1415679'},
#  '2024-09-03 14:00:00': {'1. open': '223.2400',
#   '2. high': '223.3000',
#   '3. low': '222.2600',
#   '4. close': '222.3900',
#   '5. volume': '1450189'},
#  '2024-09-03 13:45:00': {'1. open': '223.4900',
#   '2. high': '223.5500',
#   '3. low': '223.1800',
#   '4. close': '223.2100',
#   '5. volume': '641203'},
#  '2024-09-03 13:30:00': {'1. open': '223.8252',
#   '2. high': '223.9300',
#   '3. low': '223.4000',
#   '4. close': '223.4950',
#   '5. volume': '734688'},
#  '2024-09-03 13:15:00': {'1. open': '223.5799',
#   '2. high': '224.1500',
#   '3. low': '223.5400',
#   '4. close': '223.8315',
#   '5. volume': '683650'},
#  '2024-09-03 13:00:00': {'1. open': '223.7200',
#   '2. high': '224.0500',
#   '3. low': '223.5150',
#   '4. close': '223.5600',
#   '5. volume': '579836'},
#  '2024-09-03 12:45:00': {'1. open': '223.7300',
#   '2. high': '223.9100',
#   '3. low': '223.4400',
#   '4. close': '223.7100',
#   '5. volume': '607185'},
#  '2024-09-03 12:30:00': {'1. open': '223.8800',
#   '2. high': '224.0300',
#   '3. low': '223.5891',
#   '4. close': '223.7300',
#   '5. volume': '651373'},
#  '2024-09-03 12:15:00': {'1. open': '223.8650',
#   '2. high': '224.3200',
#   '3. low': '223.7300',
#   '4. close': '223.8900',
#   '5. volume': '830182'},
#  '2024-09-03 12:00:00': {'1. open': '223.5500',
#   '2. high': '223.9400',
#   '3. low': '223.3400',
#   '4. close': '223.8900',
#   '5. volume': '969782'},
#  '2024-09-03 11:45:00': {'1. open': '223.6100',
#   '2. high': '224.0200',
#   '3. low': '223.2700',
#   '4. close': '223.5400',
#   '5. volume': '977462'},
#  '2024-09-03 11:30:00': {'1. open': '223.8600',
#   '2. high': '224.4300',
#   '3. low': '223.5700',
#   '4. close': '223.5993',
#   '5. volume': '954888'},
#  '2024-09-03 11:15:00': {'1. open': '224.4700',
#   '2. high': '224.6700',
#   '3. low': '223.8200',
#   '4. close': '223.8550',
#   '5. volume': '1041296'},
#  '2024-09-03 11:00:00': {'1. open': '223.6500',
#   '2. high': '224.5300',
#   '3. low': '223.6500',
#   '4. close': '224.4500',
#   '5. volume': '1337732'},
#  '2024-09-03 10:45:00': {'1. open': '224.1800',
#   '2. high': '224.4900',
#   '3. low': '223.5100',
#   '4. close': '223.6450',
#   '5. volume': '1947565'},
#  '2024-09-03 10:30:00': {'1. open': '225.3050',
#   '2. high': '225.3050',
#   '3. low': '224.1300',
#   '4. close': '224.1620',
#   '5. volume': '1644526'},
#  '2024-09-03 10:15:00': {'1. open': '224.8700',
#   '2. high': '225.6400',
#   '3. low': '224.7300',
#   '4. close': '225.3100',
#   '5. volume': '1412638'},
#  '2024-09-03 10:00:00': {'1. open': '226.1900',
#   '2. high': '226.4800',
#   '3. low': '224.8000',
#   '4. close': '224.8600',
#   '5. volume': '1859802'},
#  '2024-09-03 09:45:00': {'1. open': '226.0400',
#   '2. high': '226.6800',
#   '3. low': '225.3000',
#   '4. close': '226.1600',
#   '5. volume': '2439265'},
#  '2024-09-03 09:30:00': {'1. open': '228.5500',
#   '2. high': '229.0000',
#   '3. low': '226.0400',
#   '4. close': '226.0550',
#   '5. volume': '4069627'},
#  '2024-09-03 09:15:00': {'1. open': '228.3035',
#   '2. high': '228.8500',
#   '3. low': '228.0600',
#   '4. close': '228.5500',
#   '5. volume': '73261'},
#  '2024-09-03 09:00:00': {'1. open': '228.0700',
#   '2. high': '230.1900',
#   '3. low': '227.8400',
#   '4. close': '228.2900',
#   '5. volume': '24023'},
#  '2024-09-03 08:45:00': {'1. open': '228.2750',
#   '2. high': '228.5600',
#   '3. low': '227.9100',
#   '4. close': '228.0000',
#   '5. volume': '22221'},
#  '2024-09-03 08:30:00': {'1. open': '228.0600',
#   '2. high': '228.3500',
#   '3. low': '227.1800',
#   '4. close': '228.2000',
#   '5. volume': '20068'},
#  '2024-09-03 08:15:00': {'1. open': '227.7800',
#   '2. high': '229.0000',
#   '3. low': '227.7300',
#   '4. close': '228.1200',
#   '5. volume': '27926'},
#  '2024-09-03 08:00:00': {'1. open': '228.8015',
#   '2. high': '229.9188',
#   '3. low': '227.4000',
#   '4. close': '227.7300',
#   '5. volume': '857358'},
#  '2024-09-03 07:45:00': {'1. open': '227.8300',
#   '2. high': '227.9100',
#   '3. low': '227.5900',
#   '4. close': '227.9000',
#   '5. volume': '21437'},
#  '2024-09-03 07:30:00': {'1. open': '227.9800',
#   '2. high': '228.1500',
#   '3. low': '227.8300',
#   '4. close': '227.8300',
#   '5. volume': '7197'},
#  '2024-09-03 07:15:00': {'1. open': '227.6000',
#   '2. high': '228.0400',
#   '3. low': '227.6000',
#   '4. close': '227.9800',
#   '5. volume': '13525'},
#  '2024-09-03 07:00:00': {'1. open': '228.1600',
#   '2. high': '228.4900',
#   '3. low': '227.5700',
#   '4. close': '227.6000',
#   '5. volume': '22519'},
#  '2024-09-03 06:45:00': {'1. open': '228.1100',
#   '2. high': '228.3400',
#   '3. low': '228.0500',
#   '4. close': '228.2100',
#   '5. volume': '2546'},
#  '2024-09-03 06:30:00': {'1. open': '228.3500',
#   '2. high': '228.3600',
#   '3. low': '228.0100',
#   '4. close': '228.1100',
#   '5. volume': '2026'},
#  '2024-09-03 06:15:00': {'1. open': '228.1500',
#   '2. high': '228.4100',
#   '3. low': '228.0800',
#   '4. close': '228.4000',
#   '5. volume': '4172'},
#  '2024-09-03 06:00:00': {'1. open': '228.3000',
#   '2. high': '228.3000',
#   '3. low': '228.0100',
#   '4. close': '228.1500',
#   '5. volume': '4490'},
#  '2024-09-03 05:45:00': {'1. open': '228.0100',
#   '2. high': '228.4800',
#   '3. low': '228.0100',
#   '4. close': '228.3000',
#   '5. volume': '4426'},
#  '2024-09-03 05:30:00': {'1. open': '228.0800',
#   '2. high': '228.1500',
#   '3. low': '227.7800',
#   '4. close': '228.0000',
#   '5. volume': '6127'},
#  '2024-09-03 05:15:00': {'1. open': '228.1300',
#   '2. high': '228.2100',
#   '3. low': '227.8000',
#   '4. close': '228.0900',
#   '5. volume': '13708'},
#  '2024-09-03 05:00:00': {'1. open': '228.5700',
#   '2. high': '228.8400',
#   '3. low': '228.0100',
#   '4. close': '228.2000',
#   '5. volume': '10980'},
#  '2024-09-03 04:45:00': {'1. open': '229.2400',
#   '2. high': '229.2500',
#   '3. low': '228.5300',
#   '4. close': '228.5800',
#   '5. volume': '7783'},
#  '2024-09-03 04:30:00': {'1. open': '229.3400',
#   '2. high': '229.4400',
#   '3. low': '229.1400',
#   '4. close': '229.2600',
#   '5. volume': '5490'},
#  '2024-09-03 04:15:00': {'1. open': '229.5500',
#   '2. high': '229.8500',
#   '3. low': '229.2600',
#   '4. close': '229.3600',
#   '5. volume': '17638'},
#  '2024-09-03 04:00:00': {'1. open': '230.5200',
#   '2. high': '230.5200',
#   '3. low': '228.8000',
#   '4. close': '229.5600',
#   '5. volume': '19351'},
#  '2024-08-30 19:45:00': {'1. open': '229.1000',
#   '2. high': '229.2200',
#   '3. low': '229.0400',
#   '4. close': '229.1500',
#   '5. volume': '7852'},
#  '2024-08-30 19:30:00': {'1. open': '229.1400',
#   '2. high': '229.1400',
#   '3. low': '229.0500',
#   '4. close': '229.0600',
#   '5. volume': '1963'},
#  '2024-08-30 19:15:00': {'1. open': '229.1900',
#   '2. high': '229.1900',
#   '3. low': '229.0400',
#   '4. close': '229.1000',
#   '5. volume': '2190'},
#  '2024-08-30 19:00:00': {'1. open': '229.1150',
#   '2. high': '229.1900',
#   '3. low': '229.0900',
#   '4. close': '229.1900',
#   '5. volume': '3835'},
#  '2024-08-30 18:45:00': {'1. open': '229.0500',
#   '2. high': '229.1500',
#   '3. low': '229.0000',
#   '4. close': '229.1150',
#   '5. volume': '4386'},
#  '2024-08-30 18:30:00': {'1. open': '229.1000',
#   '2. high': '229.1000',
#   '3. low': '229.0000',
#   '4. close': '229.0700',
#   '5. volume': '5417'},
#  '2024-08-30 18:15:00': {'1. open': '229.0700',
#   '2. high': '229.1000',
#   '3. low': '229.0000',
#   '4. close': '229.1000',
#   '5. volume': '5501'},
#  '2024-08-30 18:00:00': {'1. open': '229.0950',
#   '2. high': '229.1400',
#   '3. low': '229.0400',
#   '4. close': '229.1000',
#   '5. volume': '2721'},
#  '2024-08-30 17:45:00': {'1. open': '229.0900',
#   '2. high': '229.1500',
#   '3. low': '229.0400',
#   '4. close': '229.1400',
#   '5. volume': '4129'},
#  '2024-08-30 17:30:00': {'1. open': '229.1100',
#   '2. high': '229.1500',
#   '3. low': '229.0400',
#   '4. close': '229.1200',
#   '5. volume': '1891'},
#  '2024-08-30 17:15:00': {'1. open': '229.1200',
#   '2. high': '229.1700',
#   '3. low': '210.4149',
#   '4. close': '229.1100',
#   '5. volume': '8259'},
#  '2024-08-30 17:00:00': {'1. open': '229.0000',
#   '2. high': '229.1700',
#   '3. low': '216.7766',
#   '4. close': '229.1400',
#   '5. volume': '11374'},
#  '2024-08-30 16:45:00': {'1. open': '228.9600',
#   '2. high': '229.0900',
#   '3. low': '227.1800',
#   '4. close': '228.9750',
#   '5. volume': '58142'},
#  '2024-08-30 16:30:00': {'1. open': '228.9592',
#   '2. high': '229.0000',
#   '3. low': '228.8800',
#   '4. close': '228.9400',
#   '5. volume': '64960'},
#  '2024-08-30 16:15:00': {'1. open': '228.7400',
#   '2. high': '229.0000',
#   '3. low': '227.1800',
#   '4. close': '228.9450',
#   '5. volume': '474613'},
#  '2024-08-30 16:00:00': {'1. open': '229.0400',
#   '2. high': '230.3800',
#   '3. low': '228.5400',
#   '4. close': '228.7985',
#   '5. volume': '35850997'},
#  '2024-08-30 15:45:00': {'1. open': '228.6800',
#   '2. high': '229.8500',
#   '3. low': '228.6000',
#   '4. close': '228.8600',
#   '5. volume': '5677248'},
#  '2024-08-30 15:30:00': {'1. open': '229.0400',
#   '2. high': '229.0750',
#   '3. low': '228.3800',
#   '4. close': '228.6800',
#   '5. volume': '1245450'},
#  '2024-08-30 15:15:00': {'1. open': '228.6100',
#   '2. high': '229.0500',
#   '3. low': '228.5000',
#   '4. close': '229.0400',
#   '5. volume': '1054382'},
#  '2024-08-30 15:00:00': {'1. open': '228.5600',
#   '2. high': '228.7300',
#   '3. low': '228.2400',
#   '4. close': '228.6100',
#   '5. volume': '827090'},
#  '2024-08-30 14:45:00': {'1. open': '228.1500',
#   '2. high': '228.6900',
#   '3. low': '228.1500',
#   '4. close': '228.5600',
#   '5. volume': '766064'},
#  '2024-08-30 14:30:00': {'1. open': '228.0000',
#   '2. high': '228.3000',
#   '3. low': '227.9500',
#   '4. close': '228.1500',
#   '5. volume': '685025'},
#  '2024-08-30 14:15:00': {'1. open': '227.7500',
#   '2. high': '228.0600',
#   '3. low': '227.7000',
#   '4. close': '227.9900',
#   '5. volume': '582173'},
#  '2024-08-30 14:00:00': {'1. open': '227.7700',
#   '2. high': '227.9700',
#   '3. low': '227.6600',
#   '4. close': '227.7500',
#   '5. volume': '771763'},
#  '2024-08-30 13:45:00': {'1. open': '228.0500',
#   '2. high': '228.1200',
#   '3. low': '227.6793',
#   '4. close': '227.7600',
#   '5. volume': '587606'},
#  '2024-08-30 13:30:00': {'1. open': '228.1350',
#   '2. high': '228.3200',
#   '3. low': '228.0200',
#   '4. close': '228.0500',
#   '5. volume': '473088'},
#  '2024-08-30 13:15:00': {'1. open': '228.3600',
#   '2. high': '228.3700',
#   '3. low': '227.9200',
#   '4. close': '228.1500',
#   '5. volume': '492406'},
#  '2024-08-30 13:00:00': {'1. open': '228.3700',
#   '2. high': '228.7200',
#   '3. low': '228.2000',
#   '4. close': '228.3600',
#   '5. volume': '535291'},
#  '2024-08-30 12:45:00': {'1. open': '227.6800',
#   '2. high': '228.4900',
#   '3. low': '227.4800',
#   '4. close': '228.3600',
#   '5. volume': '729701'},
#  '2024-08-30 12:30:00': {'1. open': '228.0202',
#   '2. high': '228.0900',
#   '3. low': '227.5300',
#   '4. close': '227.6800',
#   '5. volume': '925853'},
#  '2024-08-30 12:15:00': {'1. open': '228.6900',
#   '2. high': '228.7000',
#   '3. low': '227.9400',
#   '4. close': '228.0300',
#   '5. volume': '641090'},
#  '2024-08-30 12:00:00': {'1. open': '228.6100',
#   '2. high': '228.8750',
#   '3. low': '228.0521',
#   '4. close': '228.6999',
#   '5. volume': '719136'},
#  '2024-08-30 11:45:00': {'1. open': '228.5600',
#   '2. high': '228.7750',
#   '3. low': '228.1900',
#   '4. close': '228.6200',
#   '5. volume': '825174'},
#  '2024-08-30 11:30:00': {'1. open': '228.2315',
#   '2. high': '228.6000',
#   '3. low': '227.5450',
#   '4. close': '228.5900',
#   '5. volume': '1072053'},
#  '2024-08-30 11:15:00': {'1. open': '228.3291',
#   '2. high': '228.4700',
#   '3. low': '227.7200',
#   '4. close': '228.2450',
#   '5. volume': '1182149'},
#  '2024-08-30 11:00:00': {'1. open': '228.7000',
#   '2. high': '229.0000',
#   '3. low': '228.1200',
#   '4. close': '228.3300',
#   '5. volume': '1257602'},
#  '2024-08-30 10:45:00': {'1. open': '229.5000',
#   '2. high': '229.8900',
#   '3. low': '228.5700',
#   '4. close': '228.6900',
#   '5. volume': '1121907'},
#  '2024-08-30 10:30:00': {'1. open': '229.2000',
#   '2. high': '230.0100',
#   '3. low': '229.1300',
#   '4. close': '229.5100',
#   '5. volume': '1372055'},
#  '2024-08-30 10:15:00': {'1. open': '228.7700',
#   '2. high': '229.2000',
#   '3. low': '228.6000',
#   '4. close': '229.1950',
#   '5. volume': '1291332'},
#  '2024-08-30 10:00:00': {'1. open': '229.1000',
#   '2. high': '229.3200',
#   '3. low': '228.5401',
#   '4. close': '228.7769',
#   '5. volume': '1757387'},
#  '2024-08-30 09:45:00': {'1. open': '229.8300',
#   '2. high': '230.1200',
#   '3. low': '228.8100',
#   '4. close': '229.0700',
#   '5. volume': '2089896'},
#  '2024-08-30 09:30:00': {'1. open': '230.1900',
#   '2. high': '230.4000',
#   '3. low': '229.3200',
#   '4. close': '229.8100',
#   '5. volume': '3198781'},
#  '2024-08-30 09:15:00': {'1. open': '230.7100',
#   '2. high': '230.8400',
#   '3. low': '229.6500',
#   '4. close': '230.0700',
#   '5. volume': '243551'},
#  '2024-08-30 09:00:00': {'1. open': '230.6700',
#   '2. high': '230.7700',
#   '3. low': '230.5100',
#   '4. close': '230.6900',
#   '5. volume': '27391'},
#  '2024-08-30 08:45:00': {'1. open': '230.7200',
#   '2. high': '230.9500',
#   '3. low': '230.5000',
#   '4. close': '230.7000',
#   '5. volume': '39405'},
#  '2024-08-30 08:30:00': {'1. open': '231.2500',
#   '2. high': '231.7500',
#   '3. low': '230.6563',
#   '4. close': '230.7400',
#   '5. volume': '78124'},
#  '2024-08-30 08:15:00': {'1. open': '231.0600',
#   '2. high': '231.3000',
#   '3. low': '231.0100',
#   '4. close': '231.2014',
#   '5. volume': '34292'},
#  '2024-08-30 08:00:00': {'1. open': '230.3550',
#   '2. high': '231.3000',
#   '3. low': '229.6500',
#   '4. close': '231.1000',
#   '5. volume': '86762'},
#  '2024-08-30 07:45:00': {'1. open': '230.9400',
#   '2. high': '231.0700',
#   '3. low': '230.9200',
#   '4. close': '230.9800',
#   '5. volume': '4725'},
#  '2024-08-30 07:30:00': {'1. open': '231.1000',
#   '2. high': '231.1400',
#   '3. low': '230.9100',
#   '4. close': '230.9600',
#   '5. volume': '9800'},
#  '2024-08-30 07:15:00': {'1. open': '230.9800',
#   '2. high': '231.1900',
#   '3. low': '230.8900',
#   '4. close': '231.1400',
#   '5. volume': '7191'},
#  '2024-08-30 07:00:00': {'1. open': '231.2900',
#   '2. high': '231.3000',
#   '3. low': '230.9000',
#   '4. close': '230.9700',
#   '5. volume': '17621'},
#  '2024-08-30 06:45:00': {'1. open': '230.9300',
#   '2. high': '231.2900',
#   '3. low': '230.8700',
#   '4. close': '231.2900',
#   '5. volume': '14311'},
#  '2024-08-30 06:30:00': {'1. open': '230.8900',
#   '2. high': '230.9900',
#   '3. low': '230.7500',
#   '4. close': '230.9300',
#   '5. volume': '6406'},
#  '2024-08-30 06:15:00': {'1. open': '230.9300',
#   '2. high': '230.9800',
#   '3. low': '230.8700',
#   '4. close': '230.9000',
#   '5. volume': '6676'},
#  '2024-08-30 06:00:00': {'1. open': '230.8900',
#   '2. high': '230.9300',
#   '3. low': '230.8000',
#   '4. close': '230.9300',
#   '5. volume': '2406'},
#  '2024-08-30 05:45:00': {'1. open': '230.8200',
#   '2. high': '230.8900',
#   '3. low': '230.7800',
#   '4. close': '230.8900',
#   '5. volume': '5916'},
#  '2024-08-30 05:30:00': {'1. open': '230.6700',
#   '2. high': '230.8300',
#   '3. low': '230.5400',
#   '4. close': '230.7700',
#   '5. volume': '2567'},
#  '2024-08-30 05:15:00': {'1. open': '230.8000',
#   '2. high': '230.8000',
#   '3. low': '230.6000',
#   '4. close': '230.7200',
#   '5. volume': '5248'},
#  '2024-08-30 05:00:00': {'1. open': '230.6800',
#   '2. high': '230.8200',
#   '3. low': '230.6500',
#   '4. close': '230.8200',
#   '5. volume': '2638'},
#  '2024-08-30 04:45:00': {'1. open': '230.8300',
#   '2. high': '230.8400',
#   '3. low': '230.6200',
#   '4. close': '230.6900',
#   '5. volume': '4131'},
#  '2024-08-30 04:30:00': {'1. open': '230.7700',
#   '2. high': '230.8300',
#   '3. low': '230.7200',
#   '4. close': '230.8300',
#   '5. volume': '9244'},
#  '2024-08-30 04:15:00': {'1. open': '230.7500',
#   '2. high': '230.8000',
#   '3. low': '230.7100',
#   '4. close': '230.7500',
#   '5. volume': '3509'},
#  '2024-08-30 04:00:00': {'1. open': '231.0400',
#   '2. high': '231.1100',
#   '3. low': '230.2300',
#   '4. close': '230.7200',
#   '5. volume': '12829'},
#  '2024-08-29 19:45:00': {'1. open': '230.1600',
#   '2. high': '230.2900',
#   '3. low': '230.1100',
#   '4. close': '230.2895',
#   '5. volume': '7504'},
#  '2024-08-29 19:30:00': {'1. open': '230.2850',
#   '2. high': '230.3200',
#   '3. low': '230.1500',
#   '4. close': '230.2050',
#   '5. volume': '4085'},
#  '2024-08-29 19:15:00': {'1. open': '230.2000',
#   '2. high': '230.3200',
#   '3. low': '230.1500',
#   '4. close': '230.2850',
#   '5. volume': '6934'},
#  '2024-08-29 19:00:00': {'1. open': '230.0500',
#   '2. high': '230.2230',
#   '3. low': '229.9500',
#   '4. close': '230.2000',
#   '5. volume': '7578'},
#  '2024-08-29 18:45:00': {'1. open': '230.0500',
#   '2. high': '230.1400',
#   '3. low': '229.9300',
#   '4. close': '230.0000',
#   '5. volume': '7958'},
#  '2024-08-29 18:30:00': {'1. open': '230.0250',
#   '2. high': '230.1400',
#   '3. low': '230.0000',
#   '4. close': '230.0500',
#   '5. volume': '3967'},
#  '2024-08-29 18:15:00': {'1. open': '230.0000',
#   '2. high': '230.1700',
#   '3. low': '229.7900',
#   '4. close': '230.0100',
#   '5. volume': '15438'},
#  '2024-08-29 18:00:00': {'1. open': '230.2600',
#   '2. high': '230.3500',
#   '3. low': '229.8800',
#   '4. close': '230.0600',
#   '5. volume': '29537'},
#  '2024-08-29 17:45:00': {'1. open': '230.2600',
#   '2. high': '230.3500',
#   '3. low': '230.2100',
#   '4. close': '230.3100',
#   '5. volume': '5693'},
#  '2024-08-29 17:30:00': {'1. open': '230.2250',
#   '2. high': '230.3400',
#   '3. low': '230.2100',
#   '4. close': '230.3336',
#   '5. volume': '6543'},
#  '2024-08-29 17:15:00': {'1. open': '230.2900',
#   '2. high': '230.2900',
#   '3. low': '159.5700',
#   '4. close': '230.2300',
#   '5. volume': '140140'},
#  '2024-08-29 17:00:00': {'1. open': '230.2100',
#   '2. high': '230.3000',
#   '3. low': '229.7900',
#   '4. close': '230.2500',
#   '5. volume': '218495'},
#  '2024-08-29 16:45:00': {'1. open': '230.2000',
#   '2. high': '230.2587',
#   '3. low': '229.7900',
#   '4. close': '230.2587',
#   '5. volume': '58663'},
#  '2024-08-29 16:30:00': {'1. open': '230.0900',
#   '2. high': '230.2700',
#   '3. low': '229.7900',
#   '4. close': '230.2000',
#   '5. volume': '21983'},
#  '2024-08-29 16:15:00': {'1. open': '229.8150',
#   '2. high': '230.2800',
#   '3. low': '229.7700',
#   '4. close': '230.1500',
#   '5. volume': '29452'},
#  '2024-08-29 16:00:00': {'1. open': '229.8300',
#   '2. high': '230.0000',
#   '3. low': '229.3000',
#   '4. close': '229.8150',
#   '5. volume': '10949444'},
#  '2024-08-29 15:45:00': {'1. open': '230.1000',
#   '2. high': '230.5000',
#   '3. low': '229.3300',
#   '4. close': '229.8300',
#   '5. volume': '3467998'},
#  '2024-08-29 15:30:00': {'1. open': '230.1700',
#   '2. high': '230.7800',
#   '3. low': '229.9700',
#   '4. close': '230.0800',
#   '5. volume': '1088038'},
#  '2024-08-29 15:15:00': {'1. open': '230.0900',
#   '2. high': '230.7500',
#   '3. low': '229.9400',
#   '4. close': '230.1400',
#   '5. volume': '1184480'},
#  '2024-08-29 15:00:00': {'1. open': '230.4300',
#   '2. high': '230.5100',
#   '3. low': '229.6201',
#   '4. close': '230.0900',
#   '5. volume': '1129510'},
#  '2024-08-29 14:45:00': {'1. open': '230.2900',
#   '2. high': '230.7600',
#   '3. low': '229.8500',
#   '4. close': '230.4500',
#   '5. volume': '1238654'},
#  '2024-08-29 14:30:00': {'1. open': '230.8300',
#   '2. high': '230.9700',
#   '3. low': '229.8950',
#   '4. close': '230.2800',
#   '5. volume': '1694227'},
#  '2024-08-29 14:15:00': {'1. open': '231.3000',
#   '2. high': '231.6800',
#   '3. low': '230.5500',
#   '4. close': '230.8450',
#   '5. volume': '1074248'},
#  '2024-08-29 14:00:00': {'1. open': '231.7500',
#   '2. high': '231.7500',
#   '3. low': '231.0500',
#   '4. close': '231.3200',
#   '5. volume': '877434'},
#  '2024-08-29 13:45:00': {'1. open': '231.6850',
#   '2. high': '231.9500',
#   '3. low': '231.3400',
#   '4. close': '231.7400',
#   '5. volume': '1261770'},
#  '2024-08-29 13:30:00': {'1. open': '232.1300',
#   '2. high': '232.5100',
#   '3. low': '231.6200',
#   '4. close': '231.6895',
#   '5. volume': '1183807'},
#  '2024-08-29 13:15:00': {'1. open': '232.0105',
#   '2. high': '232.3200',
#   '3. low': '231.8700',
#   '4. close': '232.1350',
#   '5. volume': '611802'},
#  '2024-08-29 13:00:00': {'1. open': '232.5300',
#   '2. high': '232.5800',
#   '3. low': '231.9500',
#   '4. close': '232.0050',
#   '5. volume': '745285'},
#  '2024-08-29 12:45:00': {'1. open': '232.4100',
#   '2. high': '232.5700',
#   '3. low': '232.0000',
#   '4. close': '232.5400',
#   '5. volume': '821995'},
#  '2024-08-29 12:30:00': {'1. open': '232.4500',
#   '2. high': '232.7100',
#   '3. low': '232.3400',
#   '4. close': '232.4200',
#   '5. volume': '1114996'},
#  '2024-08-29 12:15:00': {'1. open': '232.1900',
#   '2. high': '232.5600',
#   '3. low': '231.8400',
#   '4. close': '232.4500',
#   '5. volume': '880856'},
#  '2024-08-29 12:00:00': {'1. open': '231.6700',
#   '2. high': '232.2000',
#   '3. low': '231.6000',
#   '4. close': '232.1900',
#   '5. volume': '2088942'},
#  '2024-08-29 11:45:00': {'1. open': '231.8000',
#   '2. high': '231.9550',
#   '3. low': '231.4900',
#   '4. close': '231.6799',
#   '5. volume': '913442'},
#  '2024-08-29 11:30:00': {'1. open': '232.4476',
#   '2. high': '232.7091',
#   '3. low': '231.7600',
#   '4. close': '231.7900',
#   '5. volume': '1276007'},
#  '2024-08-29 11:15:00': {'1. open': '232.7800',
#   '2. high': '232.9200',
#   '3. low': '231.9800',
#   '4. close': '232.4500',
#   '5. volume': '1534014'},
#  '2024-08-29 11:00:00': {'1. open': '232.3400',
#   '2. high': '232.8100',
#   '3. low': '232.1717',
#   '4. close': '232.7800',
#   '5. volume': '1445216'},
#  '2024-08-29 10:45:00': {'1. open': '232.1800',
#   '2. high': '232.7249',
#   '3. low': '231.9749',
#   '4. close': '232.3700',
#   '5. volume': '2037451'},
#  '2024-08-29 10:30:00': {'1. open': '231.4200',
#   '2. high': '232.4400',
#   '3. low': '231.3800',
#   '4. close': '232.1700',
#   '5. volume': '2498500'},
#  '2024-08-29 10:15:00': {'1. open': '230.9200',
#   '2. high': '231.5200',
#   '3. low': '230.3100',
#   '4. close': '231.4200',
#   '5. volume': '1615005'},
#  '2024-08-29 10:00:00': {'1. open': '231.5800',
#   '2. high': '231.9400',
#   '3. low': '230.3300',
#   '4. close': '230.9152',
#   '5. volume': '2064011'},
#  '2024-08-29 09:45:00': {'1. open': '230.9800',
#   '2. high': '231.6600',
#   '3. low': '230.2400',
#   '4. close': '231.5700',
#   '5. volume': '3306991'},
#  '2024-08-29 09:30:00': {'1. open': '230.1000',
#   '2. high': '231.4500',
#   '3. low': '228.8800',
#   '4. close': '230.9700',
#   '5. volume': '6540756'},
#  '2024-08-29 09:15:00': {'1. open': '230.4900',
#   '2. high': '230.5000',
#   '3. low': '228.9500',
#   '4. close': '230.1300',
#   '5. volume': '408098'},
#  '2024-08-29 09:00:00': {'1. open': '230.3500',
#   '2. high': '230.4900',
#   '3. low': '225.6400',
#   '4. close': '230.4500',
#   '5. volume': '78658'},
#  '2024-08-29 08:45:00': {'1. open': '229.9100',
#   '2. high': '230.4700',
#   '3. low': '226.4900',
#   '4. close': '230.3200',
#   '5. volume': '124260'},
#  '2024-08-29 08:30:00': {'1. open': '230.1800',
#   '2. high': '230.6000',
#   '3. low': '228.9450',
#   '4. close': '229.9800',
#   '5. volume': '168227'},
#  '2024-08-29 08:15:00': {'1. open': '229.8850',
#   '2. high': '230.2900',
#   '3. low': '226.4900',
#   '4. close': '230.1200',
#   '5. volume': '74993'},
#  '2024-08-29 08:00:00': {'1. open': '229.9500',
#   '2. high': '230.4200',
#   '3. low': '226.4900',
#   '4. close': '229.8800',
#   '5. volume': '188913'},
#  '2024-08-29 07:45:00': {'1. open': '230.2700',
#   '2. high': '230.3900',
#   '3. low': '229.9600',
#   '4. close': '229.9800',
#   '5. volume': '46926'},
#  '2024-08-29 07:30:00': {'1. open': '229.8600',
#   '2. high': '230.4500',
#   '3. low': '229.8400',
#   '4. close': '230.2600',
#   '5. volume': '88206'},
#  '2024-08-29 07:15:00': {'1. open': '229.7800',
#   '2. high': '229.9900',
#   '3. low': '229.7500',
#   '4. close': '229.8500',
#   '5. volume': '38387'},
#  '2024-08-29 07:00:00': {'1. open': '229.1800',
#   '2. high': '230.0000',
#   '3. low': '229.1100',
#   '4. close': '229.8000',
#   '5. volume': '90812'},
#  '2024-08-29 06:45:00': {'1. open': '228.9900',
#   '2. high': '229.3600',
#   '3. low': '228.9200',
#   '4. close': '229.2500',
#   '5. volume': '15063'},
#  '2024-08-29 06:30:00': {'1. open': '229.2600',
#   '2. high': '229.4500',
#   '3. low': '228.9000',
#   '4. close': '228.9900',
#   '5. volume': '17325'},
#  '2024-08-29 06:15:00': {'1. open': '229.3400',
#   '2. high': '229.4300',
#   '3. low': '229.0800',
#   '4. close': '229.3600',
#   '5. volume': '13182'},
#  '2024-08-29 06:00:00': {'1. open': '229.3100',
#   '2. high': '229.8000',
#   '3. low': '229.1400',
#   '4. close': '229.2300',
#   '5. volume': '14397'},
#  '2024-08-29 05:45:00': {'1. open': '228.7900',
#   '2. high': '229.3900',
#   '3. low': '228.7700',
#   '4. close': '229.2100',
#   '5. volume': '19786'},
#  '2024-08-29 05:30:00': {'1. open': '229.1600',
#   '2. high': '229.2100',
#   '3. low': '228.7300',
#   '4. close': '228.8800',
#   '5. volume': '11208'},
#  '2024-08-29 05:15:00': {'1. open': '228.9300',
#   '2. high': '229.1900',
#   '3. low': '228.8000',
#   '4. close': '229.1800',
#   '5. volume': '30167'},
#  '2024-08-29 05:00:00': {'1. open': '228.7500',
#   '2. high': '229.0000',
#   '3. low': '228.5800',
#   '4. close': '228.9200',
#   '5. volume': '16668'},
#  '2024-08-29 04:45:00': {'1. open': '228.4000',
#   '2. high': '228.7700',
#   '3. low': '228.3800',
#   '4. close': '228.7600',
#   '5. volume': '10512'},
#  '2024-08-29 04:30:00': {'1. open': '228.2300',
#   '2. high': '228.4600',
#   '3. low': '228.2300',
#   '4. close': '228.4300',
#   '5. volume': '2672'},
#  '2024-08-29 04:15:00': {'1. open': '228.6000',
#   '2. high': '228.8100',
#   '3. low': '228.1300',
#   '4. close': '228.2300',
#   '5. volume': '13659'},
#  '2024-08-29 04:00:00': {'1. open': '226.9000',
#   '2. high': '228.8000',
#   '3. low': '226.6200',
#   '4. close': '228.5500',
#   '5. volume': '39008'},
#  '2024-08-28 19:45:00': {'1. open': '225.9360',
#   '2. high': '226.1500',
#   '3. low': '225.6500',
#   '4. close': '225.7000',
#   '5. volume': '14365'},
#  '2024-08-28 19:30:00': {'1. open': '226.1850',
#   '2. high': '226.2400',
#   '3. low': '225.8800',
#   '4. close': '225.9850',
#   '5. volume': '12771'},
#  '2024-08-28 19:15:00': {'1. open': '226.2300',
#   '2. high': '226.4000',
#   '3. low': '225.8500',
#   '4. close': '226.1100',
#   '5. volume': '11022'},
# ...
#   '2. high': '225.5000',
#   '3. low': '225.3000',
#   '4. close': '225.3100',
#   '5. volume': '9098'},
#  '2024-08-16 04:30:00': {'1. open': '225.4500',
#   '2. high': '225.6300',
#   '3. low': '225.3500',
#   '4. close': '225.4800',
#   '5. volume': '15021'},
#  '2024-08-16 04:15:00': {'1. open': '225.5700',
#   '2. high': '225.6100',
#   '3. low': '225.3000',
#   '4. close': '225.4500',
#   '5. volume': '9299'},
#  '2024-08-16 04:00:00': {'1. open': '225.3900',
#   '2. high': '225.6100',
#   '3. low': '225.3300',
#   '4. close': '225.5700',
#   '5. volume': '8751'},
#  '2024-08-15 19:45:00': {'1. open': '225.3500',
#   '2. high': '225.4000',
#   '3. low': '225.2300',
#   '4. close': '225.3250',
#   '5. volume': '7714'},
#  '2024-08-15 19:30:00': {'1. open': '225.5500',
#   '2. high': '225.5500',
#   '3. low': '225.2500',
#   '4. close': '225.3100',
#   '5. volume': '12305'},
#  '2024-08-15 19:15:00': {'1. open': '225.4100',
#   '2. high': '225.5500',
#   '3. low': '225.2200',
#   '4. close': '225.5500',
#   '5. volume': '12354'},
#  '2024-08-15 19:00:00': {'1. open': '225.4000',
#   '2. high': '225.4900',
#   '3. low': '225.1500',
#   '4. close': '225.4000',
#   '5. volume': '8578'},
#  '2024-08-15 18:45:00': {'1. open': '225.1977',
#   '2. high': '225.4582',
#   '3. low': '225.1100',
#   '4. close': '225.3900',
#   '5. volume': '11352'},
#  '2024-08-15 18:30:00': {'1. open': '225.0500',
#   '2. high': '225.3600',
#   '3. low': '224.9500',
#   '4. close': '225.1100',
#   '5. volume': '15967'},
#  '2024-08-15 18:15:00': {'1. open': '224.9150',
#   '2. high': '225.1000',
#   '3. low': '224.9100',
#   '4. close': '225.0450',
#   '5. volume': '9797'},
#  '2024-08-15 18:00:00': {'1. open': '224.8750',
#   '2. high': '224.9300',
#   '3. low': '224.8200',
#   '4. close': '224.9050',
#   '5. volume': '6728'},
#  '2024-08-15 17:45:00': {'1. open': '224.6100',
#   '2. high': '224.8750',
#   '3. low': '224.6100',
#   '4. close': '224.8750',
#   '5. volume': '3282'},
#  '2024-08-15 17:30:00': {'1. open': '224.6700',
#   '2. high': '224.9300',
#   '3. low': '224.6100',
#   '4. close': '224.7100',
#   '5. volume': '12880'},
#  '2024-08-15 17:15:00': {'1. open': '224.7000',
#   '2. high': '224.7200',
#   '3. low': '224.6600',
#   '4. close': '224.7000',
#   '5. volume': '8678'},
#  '2024-08-15 17:00:00': {'1. open': '224.7800',
#   '2. high': '224.9300',
#   '3. low': '212.6298',
#   '4. close': '224.7050',
#   '5. volume': '951280'},
#  '2024-08-15 16:45:00': {'1. open': '224.6850',
#   '2. high': '224.8200',
#   '3. low': '224.6500',
#   '4. close': '224.7800',
#   '5. volume': '24728'},
#  '2024-08-15 16:30:00': {'1. open': '224.7600',
#   '2. high': '224.8000',
#   '3. low': '224.6200',
#   '4. close': '224.6850',
#   '5. volume': '94516'},
#  '2024-08-15 16:15:00': {'1. open': '224.7200',
#   '2. high': '224.9800',
#   '3. low': '224.6800',
#   '4. close': '224.7400',
#   '5. volume': '144598'},
#  '2024-08-15 16:00:00': {'1. open': '224.7100',
#   '2. high': '224.9000',
#   '3. low': '224.2500',
#   '4. close': '224.8300',
#   '5. volume': '21467312'},
#  '2024-08-15 15:45:00': {'1. open': '224.9200',
#   '2. high': '224.9200',
#   '3. low': '223.8450',
#   '4. close': '224.7100',
#   '5. volume': '4032123'},
#  '2024-08-15 15:30:00': {'1. open': '225.0550',
#   '2. high': '225.0900',
#   '3. low': '224.8800',
#   '4. close': '224.9300',
#   '5. volume': '1033221'},
#  '2024-08-15 15:15:00': {'1. open': '225.0800',
#   '2. high': '225.1400',
#   '3. low': '224.9138',
#   '4. close': '225.0600',
#   '5. volume': '837661'},
#  '2024-08-15 15:00:00': {'1. open': '225.1100',
#   '2. high': '225.3300',
#   '3. low': '224.9400',
#   '4. close': '225.0776',
#   '5. volume': '899643'},
#  '2024-08-15 14:45:00': {'1. open': '225.0802',
#   '2. high': '225.1900',
#   '3. low': '224.9350',
#   '4. close': '225.1100',
#   '5. volume': '1418656'},
#  '2024-08-15 14:30:00': {'1. open': '225.0600',
#   '2. high': '225.1850',
#   '3. low': '225.0100',
#   '4. close': '225.0900',
#   '5. volume': '662593'},
#  '2024-08-15 14:15:00': {'1. open': '224.6900',
#   '2. high': '225.1500',
#   '3. low': '224.6900',
#   '4. close': '225.0700',
#   '5. volume': '709697'},
#  '2024-08-15 14:00:00': {'1. open': '224.6801',
#   '2. high': '224.8300',
#   '3. low': '224.6200',
#   '4. close': '224.6810',
#   '5. volume': '576949'},
#  '2024-08-15 13:45:00': {'1. open': '224.6600',
#   '2. high': '224.8000',
#   '3. low': '224.6005',
#   '4. close': '224.6761',
#   '5. volume': '689699'},
#  '2024-08-15 13:30:00': {'1. open': '224.5600',
#   '2. high': '224.8700',
#   '3. low': '224.5100',
#   '4. close': '224.6573',
#   '5. volume': '544441'},
#  '2024-08-15 13:15:00': {'1. open': '224.5200',
#   '2. high': '224.7000',
#   '3. low': '224.4200',
#   '4. close': '224.5450',
#   '5. volume': '1445732'},
#  '2024-08-15 13:00:00': {'1. open': '224.5601',
#   '2. high': '224.5601',
#   '3. low': '224.2450',
#   '4. close': '224.5100',
#   '5. volume': '620185'},
#  '2024-08-15 12:45:00': {'1. open': '224.6100',
#   '2. high': '224.6700',
#   '3. low': '224.3500',
#   '4. close': '224.5700',
#   '5. volume': '667217'},
#  '2024-08-15 12:30:00': {'1. open': '225.0000',
#   '2. high': '225.0200',
#   '3. low': '224.4500',
#   '4. close': '224.6100',
#   '5. volume': '789524'},
#  '2024-08-15 12:15:00': {'1. open': '224.7900',
#   '2. high': '225.0200',
#   '3. low': '224.7300',
#   '4. close': '224.9950',
#   '5. volume': '823894'},
#  '2024-08-15 12:00:00': {'1. open': '224.6500',
#   '2. high': '224.8500',
#   '3. low': '224.5800',
#   '4. close': '224.7600',
#   '5. volume': '599784'},
#  '2024-08-15 11:45:00': {'1. open': '224.4000',
#   '2. high': '224.8150',
#   '3. low': '224.2900',
#   '4. close': '224.6500',
#   '5. volume': '796107'},
#  '2024-08-15 11:30:00': {'1. open': '224.0100',
#   '2. high': '224.4900',
#   '3. low': '223.8400',
#   '4. close': '224.3950',
#   '5. volume': '1013773'},
#  '2024-08-15 11:15:00': {'1. open': '224.4900',
#   '2. high': '224.5800',
#   '3. low': '223.9000',
#   '4. close': '224.0050',
#   '5. volume': '1035225'},
#  '2024-08-15 11:00:00': {'1. open': '224.4400',
#   '2. high': '224.6100',
#   '3. low': '224.1700',
#   '4. close': '224.4900',
#   '5. volume': '956567'},
#  '2024-08-15 10:45:00': {'1. open': '224.8000',
#   '2. high': '225.3500',
#   '3. low': '224.3500',
#   '4. close': '224.4500',
#   '5. volume': '1434614'},
#  '2024-08-15 10:30:00': {'1. open': '224.7950',
#   '2. high': '225.2600',
#   '3. low': '224.7000',
#   '4. close': '224.8000',
#   '5. volume': '1890387'},
#  '2024-08-15 10:15:00': {'1. open': '224.7100',
#   '2. high': '224.9900',
#   '3. low': '224.4400',
#   '4. close': '224.7900',
#   '5. volume': '1489378'},
#  '2024-08-15 10:00:00': {'1. open': '224.4201',
#   '2. high': '224.7900',
#   '3. low': '223.9500',
#   '4. close': '224.7097',
#   '5. volume': '2006606'},
#  '2024-08-15 09:45:00': {'1. open': '223.0300',
#   '2. high': '224.7600',
#   '3. low': '222.9800',
#   '4. close': '224.4300',
#   '5. volume': '1930740'},
#  '2024-08-15 09:30:00': {'1. open': '224.6000',
#   '2. high': '224.8700',
#   '3. low': '222.7600',
#   '4. close': '223.0300',
#   '5. volume': '3846616'},
#  '2024-08-15 09:15:00': {'1. open': '223.4600',
#   '2. high': '224.8600',
#   '3. low': '219.9350',
#   '4. close': '224.4800',
#   '5. volume': '188999'},
#  '2024-08-15 09:00:00': {'1. open': '223.4500',
#   '2. high': '223.6400',
#   '3. low': '223.0800',
#   '4. close': '223.4242',
#   '5. volume': '59197'},
#  '2024-08-15 08:45:00': {'1. open': '223.1900',
#   '2. high': '223.7100',
#   '3. low': '221.7200',
#   '4. close': '223.4500',
#   '5. volume': '90318'},
#  '2024-08-15 08:30:00': {'1. open': '222.4300',
#   '2. high': '223.3300',
#   '3. low': '222.3000',
#   '4. close': '223.1800',
#   '5. volume': '129182'},
#  '2024-08-15 08:15:00': {'1. open': '222.3300',
#   '2. high': '222.4600',
#   '3. low': '222.2500',
#   '4. close': '222.3003',
#   '5. volume': '23873'},
#  '2024-08-15 08:00:00': {'1. open': '222.2115',
#   '2. high': '222.9188',
#   '3. low': '221.5900',
#   '4. close': '222.3300',
#   '5. volume': '34200'},
#  '2024-08-15 07:45:00': {'1. open': '222.3200',
#   '2. high': '222.3900',
#   '3. low': '222.1900',
#   '4. close': '222.2800',
#   '5. volume': '5428'},
#  '2024-08-15 07:30:00': {'1. open': '222.3000',
#   '2. high': '222.3800',
#   '3. low': '222.2200',
#   '4. close': '222.3500',
#   '5. volume': '4421'},
#  '2024-08-15 07:15:00': {'1. open': '222.0900',
#   '2. high': '222.3700',
#   '3. low': '222.0300',
#   '4. close': '222.3200',
#   '5. volume': '8454'},
#  '2024-08-15 07:00:00': {'1. open': '221.8900',
#   '2. high': '222.1500',
#   '3. low': '221.6200',
#   '4. close': '222.0900',
#   '5. volume': '13531'},
#  '2024-08-15 06:45:00': {'1. open': '221.9400',
#   '2. high': '221.9600',
#   '3. low': '221.8300',
#   '4. close': '221.8300',
#   '5. volume': '3748'},
#  '2024-08-15 06:30:00': {'1. open': '222.1500',
#   '2. high': '222.1500',
#   '3. low': '221.8400',
#   '4. close': '221.9400',
#   '5. volume': '5458'},
#  '2024-08-15 06:15:00': {'1. open': '222.3500',
#   '2. high': '222.3500',
#   '3. low': '222.0000',
#   '4. close': '222.1500',
#   '5. volume': '4399'},
#  '2024-08-15 06:00:00': {'1. open': '222.4600',
#   '2. high': '222.4800',
#   '3. low': '222.3100',
#   '4. close': '222.3100',
#   '5. volume': '3463'},
#  '2024-08-15 05:45:00': {'1. open': '222.3800',
#   '2. high': '222.4800',
#   '3. low': '222.3400',
#   '4. close': '222.4600',
#   '5. volume': '4359'},
#  '2024-08-15 05:30:00': {'1. open': '222.3000',
#   '2. high': '222.4500',
#   '3. low': '222.2700',
#   '4. close': '222.3600',
#   '5. volume': '2774'},
#  '2024-08-15 05:15:00': {'1. open': '222.2800',
#   '2. high': '222.3600',
#   '3. low': '222.2700',
#   '4. close': '222.3100',
#   '5. volume': '2490'},
#  '2024-08-15 05:00:00': {'1. open': '222.1600',
#   '2. high': '222.2900',
#   '3. low': '222.1200',
#   '4. close': '222.2900',
#   '5. volume': '1183'},
#  '2024-08-15 04:45:00': {'1. open': '222.0600',
#   '2. high': '222.2200',
#   '3. low': '222.0200',
#   '4. close': '222.2000',
#   '5. volume': '1618'},
#  '2024-08-15 04:30:00': {'1. open': '222.1900',
#   '2. high': '222.3000',
#   '3. low': '221.7500',
#   '4. close': '222.0000',
#   '5. volume': '5612'},
#  '2024-08-15 04:15:00': {'1. open': '222.3400',
#   '2. high': '222.5200',
#   '3. low': '222.1000',
#   '4. close': '222.1800',
#   '5. volume': '7231'},
#  '2024-08-15 04:00:00': {'1. open': '222.0600',
#   '2. high': '222.9000',
#   '3. low': '221.9900',
#   '4. close': '222.3700',
#   '5. volume': '8441'},
#  '2024-08-14 19:45:00': {'1. open': '221.8100',
#   '2. high': '222.1594',
#   '3. low': '221.7200',
#   '4. close': '222.0000',
#   '5. volume': '26209'},
#  '2024-08-14 19:30:00': {'1. open': '221.8850',
#   '2. high': '221.9500',
#   '3. low': '221.6900',
#   '4. close': '221.8200',
#   '5. volume': '15295'},
#  '2024-08-14 19:15:00': {'1. open': '221.8200',
#   '2. high': '221.9500',
#   '3. low': '221.6800',
#   '4. close': '221.8850',
#   '5. volume': '7516'},
#  '2024-08-14 19:00:00': {'1. open': '221.5700',
#   '2. high': '221.9400',
#   '3. low': '221.5300',
#   '4. close': '221.8200',
#   '5. volume': '6655'},
#  '2024-08-14 18:45:00': {'1. open': '221.5800',
#   '2. high': '221.6500',
#   '3. low': '221.5100',
#   '4. close': '221.5700',
#   '5. volume': '2334'},
#  '2024-08-14 18:30:00': {'1. open': '221.5700',
#   '2. high': '221.6500',
#   '3. low': '221.5000',
#   '4. close': '221.5600',
#   '5. volume': '7188'},
#  '2024-08-14 18:15:00': {'1. open': '221.8200',
#   '2. high': '221.8200',
#   '3. low': '221.5300',
#   '4. close': '221.5700',
#   '5. volume': '6789'},
#  '2024-08-14 18:00:00': {'1. open': '221.7950',
#   '2. high': '222.0400',
#   '3. low': '221.6200',
#   '4. close': '221.8200',
#   '5. volume': '3875'},
#  '2024-08-14 17:45:00': {'1. open': '221.6750',
#   '2. high': '221.8500',
#   '3. low': '221.6600',
#   '4. close': '221.8000',
#   '5. volume': '4001'},
#  '2024-08-14 17:30:00': {'1. open': '221.6400',
#   '2. high': '221.7200',
#   '3. low': '221.5800',
#   '4. close': '221.6800',
#   '5. volume': '1998463'},
#  '2024-08-14 17:15:00': {'1. open': '221.6600',
#   '2. high': '221.7000',
#   '3. low': '221.5800',
#   '4. close': '221.5800',
#   '5. volume': '3766'},
#  '2024-08-14 17:00:00': {'1. open': '221.7100',
#   '2. high': '221.7800',
#   '3. low': '221.5800',
#   '4. close': '221.6900',
#   '5. volume': '7784'},
#  '2024-08-14 16:45:00': {'1. open': '221.6900',
#   '2. high': '221.7200',
#   '3. low': '221.6000',
#   '4. close': '221.6500',
#   '5. volume': '7934'},
#  '2024-08-14 16:30:00': {'1. open': '221.6900',
#   '2. high': '221.9500',
#   '3. low': '221.5800',
#   '4. close': '221.6800',
#   '5. volume': '23741'},
#  '2024-08-14 16:15:00': {'1. open': '221.6600',
#   '2. high': '221.7200',
#   '3. low': '221.6000',
#   '4. close': '221.6700',
#   '5. volume': '33826'},
#  '2024-08-14 16:00:00': {'1. open': '221.5900',
#   '2. high': '221.9600',
#   '3. low': '221.4800',
#   '4. close': '221.6700',
#   '5. volume': '11787423'},
#  '2024-08-14 15:45:00': {'1. open': '221.8700',
#   '2. high': '222.3500',
#   '3. low': '221.5744',
#   '4. close': '221.6100',
#   '5. volume': '3133315'},
#  '2024-08-14 15:30:00': {'1. open': '221.1600',
#   '2. high': '221.8900',
#   '3. low': '221.1501',
#   '4. close': '221.8900',
#   '5. volume': '979171'},
#  '2024-08-14 15:15:00': {'1. open': '220.9105',
#   '2. high': '221.2741',
#   '3. low': '220.9105',
#   '4. close': '221.1600',
#   '5. volume': '785681'},
#  '2024-08-14 15:00:00': {'1. open': '221.5800',
#   '2. high': '221.5800',
#   '3. low': '220.8100',
#   '4. close': '220.9203',
#   '5. volume': '877296'},
#  '2024-08-14 14:45:00': {'1. open': '221.2300',
#   '2. high': '221.6000',
#   '3. low': '221.0100',
#   '4. close': '221.5700',
#   '5. volume': '743112'},
#  '2024-08-14 14:30:00': {'1. open': '221.5300',
#   '2. high': '221.6100',
#   '3. low': '221.1700',
#   '4. close': '221.2349',
#   '5. volume': '584155'},
#  '2024-08-14 14:15:00': {'1. open': '221.2500',
#   '2. high': '221.5837',
#   '3. low': '221.2000',
#   '4. close': '221.5400',
#   '5. volume': '535864'},
#  '2024-08-14 14:00:00': {'1. open': '221.2600',
#   '2. high': '221.7200',
#   '3. low': '220.9000',
#   '4. close': '221.2500',
#   '5. volume': '1047832'},
#  '2024-08-14 13:45:00': {'1. open': '221.3400',
#   '2. high': '221.7700',
#   '3. low': '221.2700',
#   '4. close': '221.2700',
#   '5. volume': '889942'},
#  '2024-08-14 13:30:00': {'1. open': '221.1700',
#   '2. high': '221.5000',
#   '3. low': '221.0904',
#   '4. close': '221.3400',
#   '5. volume': '626165'},
#  '2024-08-14 13:15:00': {'1. open': '221.3158',
#   '2. high': '221.3900',
#   '3. low': '220.9900',
#   '4. close': '221.1750',
#   '5. volume': '640094'},
#  '2024-08-14 13:00:00': {'1. open': '221.0300',
#   '2. high': '221.4650',
#   '3. low': '220.8800',
#   '4. close': '221.3200',
#   '5. volume': '1170788'},
#  '2024-08-14 12:45:00': {'1. open': '220.5900',
#   '2. high': '221.0500',
#   '3. low': '220.3800',
#   '4. close': '221.0400',
#   '5. volume': '846535'},
#  '2024-08-14 12:30:00': {'1. open': '221.3200',
#   '2. high': '221.3500',
#   '3. low': '220.5800',
#   '4. close': '220.5900',
#   '5. volume': '988551'},
#  '2024-08-14 12:15:00': {'1. open': '222.4050',
#   '2. high': '222.4499',
#   '3. low': '221.0150',
#   '4. close': '221.3050',
#   '5. volume': '1372344'},
#  '2024-08-14 12:00:00': {'1. open': '222.9700',
#   '2. high': '222.9700',
#   '3. low': '222.3500',
#   '4. close': '222.4100',
#   '5. volume': '853119'},
#  '2024-08-14 11:45:00': {'1. open': '222.4000',
#   '2. high': '223.0300',
#   '3. low': '222.4000',
#   '4. close': '222.9701',
#   '5. volume': '868994'},
#  '2024-08-14 11:30:00': {'1. open': '222.5500',
#   '2. high': '222.8900',
#   '3. low': '222.3900',
#   '4. close': '222.4100',
#   '5. volume': '935419'},
#  '2024-08-14 11:15:00': {'1. open': '222.2500',
#   '2. high': '222.5600',
#   '3. low': '222.1900',
#   '4. close': '222.5587',
#   '5. volume': '864356'},
#  '2024-08-14 11:00:00': {'1. open': '221.6950',
#   '2. high': '222.2900',
#   '3. low': '221.6000',
#   '4. close': '222.2500',
#   '5. volume': '1267512'},
#  '2024-08-14 10:45:00': {'1. open': '221.4100',
#   '2. high': '221.7300',
#   '3. low': '221.2700',
#   '4. close': '221.6901',
#   '5. volume': '1092928'},
#  '2024-08-14 10:30:00': {'1. open': '221.1100',
#   '2. high': '221.4800',
#   '3. low': '220.4550',
#   '4. close': '221.4000',
#   '5. volume': '1293040'},
#  '2024-08-14 10:15:00': {'1. open': '221.4400',
#   '2. high': '221.7000',
#   '3. low': '220.9500',
#   '4. close': '221.1300',
#   '5. volume': '1248179'},
#  '2024-08-14 10:00:00': {'1. open': '220.9450',
#   '2. high': '221.4500',
#   '3. low': '220.6900',
#   '4. close': '221.4300',
#   '5. volume': '1344993'},
#  ...}

# %%
base_url2 = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=511389.BSE&outputsize=compact&apikey='+API_KEY
res2 = requests.get(base_url2)
data2 = res2.json()   

print(data2)
# Out:
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=511389.BSE&outputsize=compact&apikey=VAWJKMGKQECBSM4S
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': '511389.BSE', '3. Last Refreshed': '2024-09-05', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2024-09-05': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-09-04': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-09-03': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-30': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-29': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-28': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-27': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-26': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-23': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-22': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-21': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-20': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-19': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-16': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-15': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-14': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-13': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-12': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-09': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-08': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-07': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-06': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-05': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-02': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-08-01': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-31': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-30': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-29': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-26': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-25': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-24': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume': '0'}, '2024-07-23': {'1. open': '7.2500', '2. high': '7.2500', '3. low': '7.2500', '4. close': '7.2500', '5. volume' ...

# %%
len(data2.get('Time Series (Daily)'))
# Out:
# 100

# %%
base_url3 = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=IBM&apikey='+API_KEY
res3 = requests.get(base_url3)
data3 = res3.json()
# print(data3)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'Intel to Deploy Gaudi 3 AI in IBM Cloud: Beneficial for INTC Stock? - IBM  ( NYSE:IBM ) , Advanced Micro Devices  ( NASDAQ:AMD ) ', 'url': 'https://www.benzinga.com/markets/asia/24/09/40687674/intel-to-deploy-gaudi-3-ai-in-ibm-cloud-beneficial-for-intc-stock', 'time_published': '20240903T185933', 'authors': ['Zacks'], 'summary': 'Intel Corporation INTC recently inked a partnership with International Business Machines Corporation IBM to deploy its Gaudi 3 AI accelerators as a service in IBM Cloud. With this, IBM became the first cloud service provider to deploy Gaudi 3 across both hybrid and on-premise environments.', 'banner_image': 'https://staticx-tuner.zacks.com/images/articles/charts/9a/76335.jpg?v=96972459', 'source': 'Benzinga', 'category_within_source': 'Trading', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.214378'}, {'topic': 'Manufacturing', 'relevance_score': '0.5'}, {'topic': 'Earnings', 'relevance_score': '0.744043'}, {'topic': 'Technology', 'relevance_score': '0.5'}], 'overall_sentiment_score': 0.065386, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'AMD', 'relevance_score': '0.088147', 'ticker_sentiment_score': '-0.08793', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'NVDA', 'relevance_score': '0.044141', 'ticker_sentiment_score': '-0.082758', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'IBM', 'relevance_score': '0.175221', 'ticker_sentiment_score': '-0.130515', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'INTC', 'relevance_score': '0.493442', 'ticker_sentiment_score': '-0.108345', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Intel to Deploy Gaudi 3 AI in IBM Cloud: Beneficial for INTC Stock?', 'url': 'https://www.zacks.com/stock/news/2330751/intel-to-deploy-gaudi-3-ai-in-ibm-cloud-beneficial-for-intc-stock', 'time_published': '20240903T121800', 'authors': ['Supriyo Bose'], 'summary': 'With declining earnings estimates and abysmal price performance compared with peers, INTC is witnessing a negative investor perception.', 'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/60/445.jpg', 'source': 'Zacks Commentary', 'category_within_source': 'n/a', 'source_domain': 'www.zacks.com', 'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.316726'}, {'topic': 'Manufacturing', 'relevance_score': '0.5'}, {'topic': 'Earnings', 'relevance_score': '0.650727'}, {'topic': 'Technology', 'relevance_score': '0.5'}], 'overall_sentiment_score': 0.029048, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'AMD', 'relevance_score': '0.090474', 'ticker_sentiment_score': '-0.007406', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'NVDA', 'relevance_score': '0.090474', 'ticker_sentiment_score': '-0.007406', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'IBM', 'relevance_score': '0.179788', 'ticker_sentiment_score': '-0.111408', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'INTC', 'relevance_score': '0.430088', 'ticker_sentiment_score': '0.023483', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Should iShares MSCI USA Min Vol Factor ETF  ( USMV )  Be on Your Investing Radar?', 'url': 'https://www.zacks.com/stock/news/2329321/should-ishares-msci-usa-min-vol-factor-etf-usmv-be-on-your-investing-radar', 'time_published': '20240830T102009', 'authors': ['Zacks Equity Research'], 'summary': 'Style Box ETF report for ...', 'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default16.jpg', 'source': 'Zacks Commentary', 'category_within_source': 'n/a', 'source_domain': 'www.zacks.com', 'topics': [{'topic': 'Financial Markets', 'relevance_score': '1.0'}, {'topic': ...

# %%
listData3 = data3.get('feed')
print(listData3[0]['title'])
print(listData3[0]['summary'])
print(listData3[0]['authors'])
print(listData3[0]['overall_sentiment_score'])
print(listData3[0]['overall_sentiment_label'])
# Out:
# Intel to Deploy Gaudi 3 AI in IBM Cloud: Beneficial for INTC Stock? - IBM  ( NYSE:IBM ) , Advanced Micro Devices  ( NASDAQ:AMD )
# Intel Corporation INTC recently inked a partnership with International Business Machines Corporation IBM to deploy its Gaudi 3 AI accelerators as a service in IBM Cloud. With this, IBM became the first cloud service provider to deploy Gaudi 3 across both hybrid and on-premise environments.
# ['Zacks']
# 0.065386
# Neutral

# %%
base_url4 = 'https://www.alphavantage.co/query?function=TOP_GAINERS_LOSERS&apikey='+API_KEY
res4 = requests.get(base_url4)
data4 = res4.json()

print(data4)
# Out:
# {'metadata': 'Top gainers, losers, and most actively traded US tickers', 'last_updated': '2024-09-05 16:15:59 US/Eastern', 'top_gainers': [{'ticker': 'LITB', 'price': '2.73', 'change_amount': '2.289', 'change_percentage': '519.0476%', 'volume': '58730'}, {'ticker': 'WHLR', 'price': '4.14', 'change_amount': '3.11', 'change_percentage': '301.9417%', 'volume': '77498049'}, {'ticker': 'KVACW', 'price': '0.068', 'change_amount': '0.033', 'change_percentage': '94.2857%', 'volume': '3203208'}, {'ticker': 'EAST', 'price': '1.44', 'change_amount': '0.679', 'change_percentage': '89.2247%', 'volume': '136687309'}, {'ticker': 'HYZNW', 'price': '0.02', 'change_amount': '0.009', 'change_percentage': '81.8182%', 'volume': '1000'}, {'ticker': 'HOTH', 'price': '1.26', 'change_amount': '0.5654', 'change_percentage': '81.3994%', 'volume': '164599802'}, {'ticker': 'BETRW', 'price': '0.0799', 'change_amount': '0.0349', 'change_percentage': '77.5556%', 'volume': '298783'}, {'ticker': 'FNVTW', 'price': '0.02', 'change_amount': '0.0081', 'change_percentage': '68.0672%', 'volume': '5408'}, {'ticker': 'COEPW', 'price': '0.029', 'change_amount': '0.0116', 'change_percentage': '66.6667%', 'volume': '1602'}, {'ticker': 'APLD', 'price': '5.37', 'change_amount': '2.13', 'change_percentage': '65.7407%', 'volume': '149113892'}, {'ticker': 'IVP', 'price': '1.17', 'change_amount': '0.452', 'change_percentage': '62.9526%', 'volume': '36805749'}, {'ticker': 'HIPO+', 'price': '0.0128', 'change_amount': '0.0049', 'change_percentage': '62.0253%', 'volume': '1155'}, {'ticker': 'AAMC', 'price': '1.81', 'change_amount': '0.69', 'change_percentage': '61.6071%', 'volume': '1779049'}, {'ticker': 'CLRCW', 'price': '0.0391', 'change_amount': '0.0147', 'change_percentage': '60.2459%', 'volume': '20000'}, {'ticker': 'ATMCW', 'price': '0.0237', 'change_amount': '0.0088', 'change_percentage': '59.0604%', 'volume': '4000'}, {'ticker': 'BAERW', 'price': '0.049', 'change_amount': '0.0179', 'change_percentage': '57.5563%', 'volume': '30000'}, {'ticker': 'ALFUW', 'price': '0.12', 'change_amount': '0.0398', 'change_percentage': '49.6259%', 'volume': '51860'}, {'ticker': 'TVGNW', 'price': '0.0281', 'change_amount': '0.0092', 'change_percentage': '48.6772%', 'volume': '1146'}, {'ticker': 'EDBLW', 'price': '0.0121', 'change_amount': '0.0039', 'change_percentage': '47.561%', 'volume': '2197'}, {'ticker': 'CELUW', 'price': '0.0177', 'change_amount': '0.0057', 'change_percentage': '47.5%', 'volume': '200'}], 'top_losers': [{'ticker': 'IVDAW', 'price': '0.026', 'change_amount': '-0.045', 'change_percentage': '-63.3803%', 'volume': '33203'}, {'ticker': 'SGLY', 'price': '2.48', 'change_amount': '-4.25', 'change_percentage': '-63.1501%', 'volume': '2517836'}, {'ticker': 'CTV+', 'price': '0.016', 'change_amount': '-0.0241', 'change_percentage': '-60.0998%', 'volume': '10074'}, {'ticker': 'NUKKW', 'price': '0.0082', 'change_amount': '-0.0083', 'change_percentage': '-50.303%', 'volume': '81539'}, {'ticker': 'SLXNW', 'price': '0.0425', 'change_amount': '-0.0375', 'change_percentage': '-46.875%', 'volume': '80182'}, {'ticker': 'SABSW', 'price': '0.026', 'change_amount': '-0.0209', 'change_percentage': '-44.5629%', 'volume': '3000'}, {'ticker': 'BKSY+', 'price': '0.0333', 'change_amount': '-0.0266', 'change_percentage': '-44.4073%', 'volume': '161050'}, {'ticker': 'LANV+', 'price': '0.0161', 'change_amount': '-0.0127', 'change_percentage': '-44.0972%', 'volume': '10800'}, {'ticker': 'NVNIW', 'price': '0.022', 'change_amount': '-0.017', 'change_percentage': '-43.5897%', 'volume': '521'}, {'ticker': 'BCGWW', 'price': '0.0401', 'change_amount': '-0.0295', 'change_percentage': '-42.3851%', 'volume': '4762'}, {'ticker': 'PBMWW', 'price': '0.0171', 'change_amount': '-0.0124', 'change_percentage': '-42.0339%', 'volume': '3364'}, {'ticker': 'PNST+', 'price': '0.0383', 'change_amount': '-0.0267', 'change_percentage': '-41.0769%', 'volume': '376793'}, {'ticker': 'SOAR+', 'price': '0.01', 'change_amount': '-0. ...

# %%
listData4_0 = data4.get('top_gainers')
listData4_1 = data4.get('top_losers')
listData4_2 = data4.get('most_actively_traded')
for i in range(len(listData4_0)):
    print(listData4_0[i]['ticker']+' '+listData4_1[i]['ticker']+' '+listData4_2[i]['ticker'])
# Out:
# LITB IVDAW NVDA
# WHLR SGLY SQQQ
# KVACW CTV+ HOTH
# EAST NUKKW APLD
# HYZNW SLXNW EAST
# HOTH SABSW TSLA
# BETRW BKSY+ WTO
# FNVTW LANV+ NIO
# COEPW NVNIW SOXL
# APLD BCGWW EFV
# IVP PBMWW WHLR
# HIPO+ PNST+ TSLL
# AAMC SOAR+ INTC
# CLRCW BNAIW SOXS
# ATMCW MMVWW FCEL
# BAERW RENEW IUSB
# ALFUW RSVRW TQQQ
# TVGNW APLMW SPXS
# EDBLW AZI F
# CELUW YOTAW TLT

# %%
base_url5 = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=IBM&apikey='+API_KEY
res5 = requests.get(base_url5)
data5 = res5.json()

# print(data5)

# %%
listData5_0 = data5.get('annualReports')
count=5
for d in listData5_0:
    if count==0: break
    count-=1
    print(d['netIncome'])
print('\n')
listData5_1  = data5.get('quarterlyReports')
for d in listData5_1:
    if count==5: break
    count+=1
    print(d['netIncome'])
# Out:
# 7502000000
# 1639000000
# 5743000000
# 5590000000
# 9431000000
#
#
# 1605000000
# 3288000000
# 1704000000
# 1583000000
# 927000000

# %%
base_url6 = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=USD&to_currency=INR&apikey='+API_KEY
res6 = requests.get(base_url6)
data6 = res6.json()

print(data6)
# Out:
# {'Realtime Currency Exchange Rate': {'1. From_Currency Code': 'USD', '2. From_Currency Name': 'United States Dollar', '3. To_Currency Code': 'INR', '4. To_Currency Name': 'Indian Rupee', '5. Exchange Rate': '83.89400000', '6. Last Refreshed': '2024-09-06 15:53:34', '7. Time Zone': 'UTC', '8. Bid Price': '83.89370000', '9. Ask Price': '83.89790000'}}

# %%
print(data6.get('Realtime Currency Exchange Rate')['5. Exchange Rate'])
# Out:
# 83.89400000
