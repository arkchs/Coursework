# %% [markdown]
# ### 70 30 train test split

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('salary_data.csv')
X=df['YearsExperience']
y=df['Salary']

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# ### No missing values or outliers

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(df['YearsExperience'])
# Out:
# <Axes: ylabel='YearsExperience'>

# %%
sns.boxplot(df['Salary'])
# Out:
# <Axes: ylabel='Salary'>

# %%
plt.plot(df['YearsExperience'], df['Salary'])

# %% [markdown]
# ### Performing Data Smoothing using Exponetial data smoothing and moving averages

# %% [markdown]
# ### manual lsr

# %%
def error(X,Y,Bo,B1):
    error_sum=0
    for i in range(0,len(Y)-1):
        error_sum+=(Y[i]-(Bo+B1*X[i]))**2
    return error_sum/len(Y)

# %%
def gradient(X,Y,Bo,B1,alpha):
    for i in range(0,len(X)):
        df_dBo = (-Y+Bo+B1*X)
        Bo = Bo-(alpha*df_dBo)
        df_dB1 = (-Y*X+Bo*X+B1*X*X)
        B1 = B1-(alpha*df_dB1)
    return []

# %%
def gradient_descent(X,Y,Bo,B1):
    alpha = 0.1 
    while(True):
        mse = error(X,Y,Bo,B1)

# %% [markdown]
# ### 90 10
# ### 80 20
# ### 70 30
# ### 60 40
# ### 50 50

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=1)

# %% [markdown]
# ### Create folds in the data as in create 5 folds in the data
# ### then use the first fold as the test data then second fold then the third fold and so on.
